# %% [markdown]
# **Table of contents**<a id='toc0_'></a>
# - [Data Mining Lab 2 - Phase 2](#toc1_)
#   - [Before Starting](#toc1_1_)
#   - [Introduction](#toc1_2_)
#   - [**1. Data Preparation**](#toc1_3_)
#   - [**1.1 Load data**](#toc1_4_)
#     - [**1.2 Save data**](#toc1_4_1_)
#   - [**2. Large Language Models (LLMs)**](#toc1_5_)
#     - [Open-Source vs. Proprietary LLMs](#toc1_5_1_)
#     - [Why Use Code (API) for Data Mining?](#toc1_5_2_)
#     - [The Gemini API](#toc1_5_3_)
#     - [Interacting with the Gemini API](#toc1_5_4_)
#     - [**2.1 Text Prompting**](#toc1_5_5_)
#         - [**>>> Exercise 1 (Take home):**](#toc1_5_5_1_1_)
#     - [**2.2 Structured Output**](#toc1_5_6_)
#         - [**>>> Exercise 2 (Take home):**](#toc1_5_6_1_1_)
#     - [**2.3 Information Extraction and Grounding:**](#toc1_5_7_)
#       - [**`langextract`: A Library for Grounded Extraction**](#toc1_5_7_1_)
#         - [**2.3.1 Using PDF Documents:**](#toc1_5_7_1_1_)
#         - [**>>> Bonus Exercise 3 (Take home):**](#toc1_5_7_1_2_)
#     - [**2.4 Generating LLM Embeddings:**](#toc1_5_8_)
#         - [**>>> Exercise 4 (Take home):**](#toc1_5_8_1_1_)
#     - [**2.5 Retrieval-Augmented Generation (RAG)**](#toc1_5_9_)
#         - [**Actual answer in the URL:**](#toc1_5_9_1_1_)
#         - [**Content in the URL that might get into the generated answer because of similar semantic meaning:**](#toc1_5_9_1_2_)
#         - [**>>> Bonus Exercise 5 (Take home):**](#toc1_5_9_1_3_)
#     - [**2.6 Few-Shot Prompting Classification:**](#toc1_5_10_)
#         - [**>>> Exercise 6 (Take home):**](#toc1_5_10_1_1_)
#         - [**>>> Exercise 7 (Take home):**](#toc1_5_10_1_2_)
#     - [**2.7 Extra LLM Related Materials:**](#toc1_5_11_)
#
# <!-- vscode-jupyter-toc-config
# 	numbering=false
# 	anchor=true
# 	flat=false
# 	minLevel=1
# 	maxLevel=6
# 	/vscode-jupyter-toc-config -->
# <!-- THIS CELL WILL BE REPLACED ON TOC UPDATE. DO NOT WRITE YOUR TEXT IN THIS CELL -->

# %% [markdown]
# # <a id='toc1_'></a>[Data Mining Lab 2 - Phase 2](#toc0_)
# In this lab's phase 2 session we will focus on exploring some basic LLMs' applications with data.

# %% [markdown]
# ## <a id='toc1_1_'></a>[Before Starting](#toc0_)
#
# **Make sure you have installed all the required libraries and you have the environment ready to run this lab.**

# %% [markdown]
# ---
# ## <a id='toc1_2_'></a>[Introduction](#toc0_)

# %% [markdown]
# **Dataset:** [SemEval 2017 Task](https://competitions.codalab.org/competitions/16380)
#
# **Task:** Classify text data into 4 different emotions using word embeddings and other deep information retrieval approaches.
#
# ![pic0.png](./pics/pic0.png)

# %% [markdown]
# ---
# ## <a id='toc1_3_'></a>[**1. Data Preparation**](#toc0_)

# %% [markdown]
# ---
# ## <a id='toc1_4_'></a>[**1.1 Load data**](#toc0_)
#
# We start by loading the csv files into a single pandas dataframe for training and one for testing.

# %%
import pandas as pd

### training data
anger_train = pd.read_csv("data/semeval/train/anger-ratings-0to1.train.txt",
                         sep="\t", header=None,names=["id", "text", "emotion", "intensity"])
sadness_train = pd.read_csv("data/semeval/train/sadness-ratings-0to1.train.txt",
                         sep="\t", header=None, names=["id", "text", "emotion", "intensity"])
fear_train = pd.read_csv("data/semeval/train/fear-ratings-0to1.train.txt",
                         sep="\t", header=None, names=["id", "text", "emotion", "intensity"])
joy_train = pd.read_csv("data/semeval/train/joy-ratings-0to1.train.txt",
                         sep="\t", header=None, names=["id", "text", "emotion", "intensity"])

# %%
# combine 4 sub-dataset
train_df = pd.concat([anger_train, fear_train, joy_train, sadness_train], ignore_index=True)

# %%
### testing data
anger_test = pd.read_csv("data/semeval/dev/anger-ratings-0to1.dev.gold.txt",
                         sep="\t", header=None, names=["id", "text", "emotion", "intensity"])
sadness_test = pd.read_csv("data/semeval/dev/sadness-ratings-0to1.dev.gold.txt",
                         sep="\t", header=None, names=["id", "text", "emotion", "intensity"])
fear_test = pd.read_csv("data/semeval/dev/fear-ratings-0to1.dev.gold.txt",
                         sep="\t", header=None, names=["id", "text", "emotion", "intensity"])
joy_test = pd.read_csv("data/semeval/dev/joy-ratings-0to1.dev.gold.txt",
                         sep="\t", header=None, names=["id", "text", "emotion", "intensity"])

# combine 4 sub-dataset
test_df = pd.concat([anger_test, fear_test, joy_test, sadness_test], ignore_index=True)
train_df.head()
# Out:
#       id                                               text emotion  intensity
# 0  10000  How the fu*k! Who the heck! moved my fridge!.....   anger      0.938
# 1  10001  So my Indian Uber driver just called someone t...   anger      0.896
# 2  10002  @DPD_UK I asked for my parcel to be delivered ...   anger      0.896
# 3  10003  so ef whichever butt wipe pulled the fire alar...   anger      0.896
# 4  10004  Don't join @BTCare they put the phone down on ...   anger      0.896

# %%
# shuffle dataset
train_df = train_df.sample(frac=1)
test_df = test_df.sample(frac=1)

# %%
print("Shape of Training df: ", train_df.shape)
print("Shape of Testing df: ", test_df.shape)
# Out:
# Shape of Training df:  (3613, 4)
# Shape of Testing df:  (347, 4)

# %% [markdown]
# ---
# ### <a id='toc1_4_1_'></a>[**1.2 Save data**](#toc0_)

# %%
# save to pickle file
train_df.to_pickle("./data/train_df.pkl") 
test_df.to_pickle("./data/test_df.pkl")

# %%
import pandas as pd

# load a pickle file
train_df = pd.read_pickle("./data/train_df.pkl")
test_df = pd.read_pickle("./data/test_df.pkl")

# %% [markdown]
# For more information: https://reurl.cc/0Dzqx

# %% [markdown]
# ---
# ## <a id='toc1_5_'></a>[**2. Large Language Models (LLMs)**](#toc0_)
#
# Before we start we strongly suggest that you watch the following video explanations so you can understand the concepts that we are gonna discuss about LLMs:
#
# 1. [How Large Language Models Work](https://www.youtube.com/watch?v=5sLYAQS9sWQ)
# 2. [Large Language Models explained briefly](https://www.youtube.com/watch?v=LPZh9BOjkQs)
# 3. [What is Prompt Tuning?](https://www.youtube.com/watch?v=yu27PWzJI_Y)
# 4. [Why Large Language Models Hallucinate](https://www.youtube.com/watch?v=cfqtFvWOfg0)
# 5. [What are LLM Embeddings?](https://www.youtube.com/watch?v=UShw_1NbpCw&t=182s)
# 6. [What is Retrieval-Augmented Generation (RAG)?](https://www.youtube.com/watch?v=T-D1OfcDW1M)
# 7. [RAG vs Fine-Tuning vs Prompt Engineering: Optimizing AI Models](https://www.youtube.com/watch?v=zYGDpG-pTho)
# 8. [Discover Few-Shot Prompting | Google AI Essentials](https://www.youtube.com/watch?v=9qdgEBVkWR4)
# 9. [What is Zero-Shot Learning?](https://www.youtube.com/watch?v=pVpr4GYLzAo)
# 10. [Zero-shot, One-shot and Few-shot Prompting Explained | Prompt Engineering 101](https://www.youtube.com/watch?v=sW5xoicq5TY)
#
# `These videos can help you get a better grasp on the core concepts of LLMs if you were not familiar before.`
#
# **So now let's start with the main content of Lab 2 Phase 2.**
#
# Large Language Models (LLMs) are AI systems trained on vast amounts of text to understand and generate human language for tasks like summarization and translation.
#
# ### <a id='toc1_5_1_'></a>[Open-Source vs. Proprietary LLMs](#toc0_)
# *   **Open-Source Models** (e.g., Llama, Gemma) are customizable and cost-effective but require technical skill to manage and may be less powerful.
# *   **Proprietary Models** (e.g., Gemini, ChatGPT) offer top performance and ease of use but are more costly and less flexible.
#
# For students interested in running models locally, the optional notebook `DM2025-Lab2-Optional-Ollama.ipynb` explores using Ollama ([Ollama GitHub Link](https://github.com/ollama/ollama)). It needs a capable GPU to run models (**at least 4GB VRAM**).
#
# You can explore the variety of models available through Ollama here:
#
# ![pic10.png](./pics/pic10.png)
#
# ### <a id='toc1_5_2_'></a>[Why Use Code (API) for Data Mining?](#toc0_)
#
# For data analysis, accessing LLMs programmatically is superior to using web chatbots because it allows for:
# *   **Automation:** Easily process entire datasets with loops.
# *   **Structured Output:** Receive data in usable formats like **JSON**, ready for analysis in tools like pandas.
# *   **Reproducibility:** Ensure consistent results by setting fixed parameters.
# *   **Privacy:** Maintain data security, especially when running models locally.
#
# For the main exercises in this lab, we will use **the Gemini API**. This approach offers several advantages over running local open-source models, such as access to state-of-the-art model performance without needing specialized hardware. While the API has usage limits (rate limits and token quotas), it provides a generous **free tier** that is more than sufficient for our exercises.
#
# ![pic13.png](./pics/pic13.png)
#
# ![pic14.png](./pics/pic14.png)
#
# ### <a id='toc1_5_3_'></a>[The Gemini API](#toc0_)
#
# We will primarily use the **Gemini 2.5 Flash-Lite** (`gemini-2.5-flash-lite`) model. As shown in the rate limit table, this model is optimized for high-frequency tasks and offers a high request-per-day limit of 1,000, making it ideal for completing the lab exercises without interruption.
#
# Students are encouraged to explore other models available through the API but should remain mindful of their respective usage limits. For instance:
# *   **Gemini 2.5 Pro** is a more powerful model but has a lower daily request limit of 100.
# *   The **Gemma 3** model available via the API offers an impressive 14,400 requests per day, providing another excellent alternative for experimentation.
#
# Please be aware of your usage limits as you work through the exercises to ensure you do not get rate-limited.
#
# [Gemini Documentation](https://ai.google.dev/gemini-api/docs)
#
# [Gemini Rate Limits](https://ai.google.dev/gemini-api/docs/rate-limits)
#
# [Description of Gemini Models](https://ai.google.dev/gemini-api/docs/models)

# %% [markdown]
# ---
#
# ### <a id='toc1_5_4_'></a>[Interacting with the Gemini API](#toc0_)
#
# The code cell below contains the primary function, `prompt_gemini`, that we will use throughout this lab to communicate with the Gemini API. It's designed to be a flexible wrapper that handles the details of sending a request and receiving a response.
#
# Before you run the exercises, here are the key things you need to understand in this setup:
#
# *   **API Key Configuration**: The script loads your API key from a `.env` file located in the `./config/` directory. **You must create this file and add your API key** like this: `GOOGLE_API_KEY='YOUR_API_KEY_HERE'`. This is a security best practice to keep your credentials out of the code.
#
# *   **Global Settings**: At the top of the script, you can find and modify several important defaults:
#     *   `MODEL_NAME`: We've set this to `"gemini-2.5-flash-lite"`, but you can easily switch to other models like `"gemini-2.5-pro"` to experiment.
#     *   `SYSTEM_INSTRUCTION`: This sets the model's default behavior or persona (e.g., "You are a helpful assistant"). You can customize this for different tasks.
#     *   `SAFETY_SETTINGS`: For our academic exercises, these are turned off to prevent interference. In real-world applications, you would configure these carefully.
#
# *   **The `prompt_gemini` function**: This is the main tool you will use. Here are its most important parameters:
#     *   `input_prompt`: The list of contents (text, images, etc.) you want to send to the model.
#     *   `temperature`: Controls the randomness of the output. `0.0` makes the output deterministic and less creative, while a higher value (e.g., `0.7`) makes it more varied.
#     *   `schema`: A powerful feature that allows you to specify a JSON format for the model's output. This is extremely useful for structured data extraction.
#     *   `with_tokens_info`: If set to `True`, the function will also return the number of input and output tokens used, which is helpful for monitoring your usage against the free tier limits.
#
# In the following exercises, you will call this function with different prompts and configurations to solve various tasks.
#
# If needed, you can also check some tutorials on how a python function works: [Python Functions Tutorial](https://realpython.com/defining-your-own-python-function/)

# %%
import os
from dotenv import load_dotenv
from google import genai
from google.genai import types

env_path = "./config/.env"
load_dotenv(dotenv_path=env_path)

# System instruction that can dictate how the model behaves in the output, can be customized as needed
SYSTEM_INSTRUCTION = (
        "You are a helpful assistant"
    )

# Max amount of tokens that the model can output, the Gemini 2.5 Models have this maximum amount
# For other models need to check their documentation 
MAX_OUTPUT_TOKENS = 65535
MODEL_NAME = "gemini-2.5-flash-lite" # Other models: "gemini-2.5-pro", "gemini-2.5-flash"; Check different max output tokens: "gemini-2.0-flash" , "gemini-2.0-flash-lite" 

# We disable the safety settings, as no moderation is needed in our tasks
SAFETY_SETTINGS = [
    types.SafetySetting(
        category="HARM_CATEGORY_HATE_SPEECH", threshold="OFF"),
    types.SafetySetting(
        category="HARM_CATEGORY_DANGEROUS_CONTENT", threshold="OFF"),
    types.SafetySetting(
        category="HARM_CATEGORY_SEXUALLY_EXPLICIT", threshold="OFF"),
    types.SafetySetting(
        category="HARM_CATEGORY_HARASSMENT", threshold="OFF")
]

#IMPORTANT: The script loads your API key from a `.env` file located in the `./config/` directory. 
# You must create this file and add your API key like this: `GOOGLE_API_KEY='YOUR_API_KEY_HERE'`

# We input the API Key to be able to use the Gemini models
api_key = os.getenv("GOOGLE_API_KEY")
os.environ["GOOGLE_API_KEY"] = api_key
client = genai.Client(api_key=api_key)

# We also set LangExtract to use the API key as well:
if 'GEMINI_API_KEY' not in os.environ:
    os.environ['GEMINI_API_KEY'] = api_key

def prompt_gemini(
        input_prompt: list,
        schema = None,
        temperature: float = 0.0,
        system_instruction: str = SYSTEM_INSTRUCTION,
        max_output_tokens: int = MAX_OUTPUT_TOKENS,
        client: genai.Client = client,
        model_name: str = MODEL_NAME,
        new_config: types.GenerateContentConfig = None,
        with_tools: bool = False,
        with_parts: bool = False,
        with_tokens_info: bool = False
    ):
        try:
            # If we need a JSON schema we set up the following
            if schema:
                generate_content_config = types.GenerateContentConfig(
                    temperature=temperature,
                    system_instruction=system_instruction,
                    max_output_tokens=max_output_tokens,
                    response_modalities=["TEXT"],
                    response_mime_type="application/json",
                    response_schema=schema,
                    safety_settings=SAFETY_SETTINGS
                )
            # If there is no need we leave it unstructured
            else:
                generate_content_config = types.GenerateContentConfig(
                    temperature=temperature,
                    system_instruction=system_instruction,
                    max_output_tokens=max_output_tokens,
                    response_modalities=["TEXT"],
                    safety_settings=SAFETY_SETTINGS
                )
            
            # We add a different custom configuration if we need it
            if new_config:
                generate_content_config = new_config
            
            # For some tasks we need a more specific way to add the contents when prompting the model
            # So we need custom parts for it sometimes from the "types" objects
            if with_parts:
                response = client.models.generate_content(
                    model=model_name,
                    contents=types.Content(parts=input_prompt),
                    config=generate_content_config,
                )
            # In the simplest form the contents can be expressed as a list [] of simple objects like str and Pillow images
            else:
                response = client.models.generate_content(
                    model=model_name,
                    contents=input_prompt,
                    config=generate_content_config,
                )

            if with_tools:
                # print(response)
                # Include raw response when function calling
                completion = response
                if with_tokens_info:
                    log = {
                        "model": model_name,
                        "input_tokens": response.usage_metadata.prompt_token_count,
                        "output_tokens": response.usage_metadata.candidates_token_count,
                    }
                    return completion, log
                return completion
            else:
                completion = response.text
                if with_tokens_info:
                    log = {
                        "model": model_name,
                        "input_tokens": response.usage_metadata.prompt_token_count,
                        "output_tokens": response.usage_metadata.candidates_token_count,
                    }
                    # Return the text response and logs (if selected)
                    return completion, log
                return completion
        except Exception as e:
             print(f"Error occurred when generating response, error: {e}")
             return None
# Out:
# Both GOOGLE_API_KEY and GEMINI_API_KEY are set. Using GOOGLE_API_KEY.

# %% [markdown]
# ---
# ### <a id='toc1_5_5_'></a>[**2.1 Text Prompting**](#toc0_)
#
# In the same way as with ChatGPT we can use the Gemini models to ask about anything. Here we are going to ask a question requesting the response to be in markdown format, this is to make it have a better display afterwards.
#
# For more information visit:
# [Gemini's Text Generation Documentation](https://ai.google.dev/gemini-api/docs/text-generation)

# %%
input_prompt = ["What is Data Mining?"]
text_response, logs = prompt_gemini(input_prompt = input_prompt, with_tokens_info = True)
print(text_response)
# Out:
# Data mining is the process of **discovering patterns, insights, and knowledge from large datasets**. It's essentially about extracting valuable information that isn't immediately obvious from raw data. Think of it as sifting through a mountain of information to find hidden gems.
#
# Here's a breakdown of what that means:
#
# **Key Concepts:**
#
# *   **Large Datasets:** Data mining is typically applied to datasets that are too large and complex for manual analysis. This can include customer transaction records, website logs, sensor data, social media feeds, scientific experiment results, and much more.
# *   **Patterns and Insights:** The goal is to identify recurring trends, correlations, anomalies, and relationships within the data. These patterns can reveal underlying structures, predict future behavior, or explain observed phenomena.
# *   **Knowledge Discovery:** The ultimate aim is to transform raw data into actionable knowledge that can be used for decision-making, problem-solving, and strategic planning.
#
# **How it Works (The Process):**
#
# Data mining is usually an iterative process that involves several stages:
#
# 1.  **Business Understanding:** Defining the problem or objective you want to achieve with data mining. What questions are you trying to answer? What business goals are you trying to meet?
# 2.  **Data Understanding:** Exploring and getting familiar with the data. This involves collecting, cleaning, and understanding the data's structure, quality, and meaning.
# 3.  **Data Preparation (Preprocessing):** This is often the most time-consuming stage. It involves:
#     *   **Cleaning:** Handling missing values, noisy data, and inconsistencies.
#     *   **Integration:** Combining data from multiple sources.
#     *   **Transformation:** Normalizing or aggregating data to make it suitable for mining.
#     *   **Reduction:** Reducing the size of the dataset while preserving important information.
# 4.  **Modeling:** Selecting and applying appropriate data mining techniques (algorithms) to discover patterns. This is where the "mining" happens.
# 5.  **Evaluation:** Assessing the quality and usefulness of the discovered patterns. Do they make sense? Are they statistically significant? Do they meet the business objectives?
# 6.  **Deployment:** Putting the discovered knowledge into practice. This could involve integrating it into business processes, creating reports, or building predictive models.
#
# **Common Data Mining Techniques:**
#
# Data mining employs a variety of techniques, often drawing from statistics, machine learning, and database systems. Some of the most common include:
#
# *   **Classification:** Categorizing data into predefined classes (e.g., predicting whether a customer will churn or not).
# *   **Clustering:** Grouping similar data points together without predefined classes (e.g., segmenting customers into different groups based on their purchasing behavior).
# *   **Association Rule Mining:** Discovering relationships between items in a dataset (e.g., "customers who buy bread also tend to buy milk"). This is often used in market basket analysis.
# *   **Regression:** Predicting a continuous numerical value (e.g., predicting the price of a house based on its features).
# *   **Anomaly Detection (Outlier Detection):** Identifying data points that deviate significantly from the norm (e.g., detecting fraudulent transactions).
# *   **Sequential Pattern Mining:** Discovering patterns that occur in a sequence over time (e.g., identifying common user navigation paths on a website).
#
# **Why is Data Mining Important?**
#
# Data mining is crucial for businesses and organizations because it enables them to:
#
# *   **Make Better Decisions:** By understanding customer behavior, market trends, and operational efficiencies, organizations can make more informed and strategic decisions.
# *   **Improve Customer Relationships:** Identifying customer preferences and predicting their needs allows for personalized marketing, better customer service, and increased loyalty.
# *   **Detect Fraud and Risk:** Anomaly detection can help identify fraudulent activities, security breaches, and potential risks.
# *   **Optimize Operations:** Understanding patterns in operational data can lead to improved efficiency, reduced costs, and better resource allocation.
# *   **Drive Innovation:** Discovering new insights can spark new product development, service offerings, and business models.
# *   **Gain a Competitive Advantage:** Organizations that effectively leverage data mining can outperform their competitors by understanding their market and customers better.
#
# In essence, data mining is a powerful tool for transforming raw data into valuable intelligence, driving progress and innovation across various fields.

# %% [markdown]
# We can also check the logs of the usage with our model that we defined in our previous function. We can observe the model we used, how many tokens where in the prompt in the input, and the output text response tokens of our model.

# %%
print(logs)
# Out:
# {'model': 'gemini-2.5-flash-lite', 'input_tokens': 12, 'output_tokens': 911}

# %% [markdown]
# **We can use the IPython library to make the response look better:**

# %%
from IPython.display import display, Markdown
display(Markdown(text_response))
# Out:
# Data mining is the process of **discovering patterns, insights, and knowledge from large datasets**. It's essentially about extracting valuable information that isn't immediately obvious from raw data. Think of it as sifting through a mountain of information to find hidden gems.
#
# Here's a breakdown of what that means:
#
# **Key Concepts:**
#
# *   **Large Datasets:** Data mining is typically applied to datasets that are too large and complex for manual analysis. This can include customer transaction records, website logs, sensor data, social media feeds, scientific experiment results, and much more.
# *   **Patterns and Insights:** The goal is to identify recurring trends, correlations, anomalies, and relationships within the data. These patterns can reveal underlying structures, predict future behavior, or explain observed phenomena.
# *   **Knowledge Discovery:** The ultimate aim is to transform raw data into actionable knowledge that can be used for decision-making, problem-solving, and strategic planning.
#
# **How it Works (The Process):**
#
# Data mining is usually an iterative process that involves several stages:
#
# 1.  **Business Understanding:** Defining the problem or objective you want to achieve with data mining. What questions are you trying to answer? What business goals are you trying to meet?
# 2.  **Data Understanding:** Exploring and getting familiar with the data. This involves collecting, cleaning, and understanding the data's structure, quality, and meaning.
# 3.  **Data Preparation (Preprocessing):** This is often the most time-consuming stage. It involves:
#     *   **Cleaning:** Handling missing values, noisy data, and inconsistencies.
#     *   **Integration:** Combining data from multiple sources.
#     *   **Transformation:** Normalizing or aggregating data to make it suitable for mining.
#     *   **Reduction:** Reducing the size of the dataset while preserving important information.
# 4.  **Modeling:** Selecting and applying appropriate data mining techniques (algorithms) to discover patterns. This is where the "mining" happens.
# 5.  **Evaluation:** Assessing the quality and usefulness of the discovered patterns. Do they make sense? Are they statistically significant? Do they meet the business objectives?
# 6.  **Deployment:** Putting the discovered knowledge into practice. This could involve integrating it into business processes, creating reports, or building predictive models.
#
# **Common Data Mining Techniques:**
#
# Data mining employs a variety of techniques, often drawing from statistics, machine learning, and database systems. Some of the most common include:
#
# *   **Classification:** Categorizing data into predefined classes (e.g., predicting whether a customer will churn or not).
# *   **Clustering:** Grouping similar data points together without predefined classes (e.g., segmenting customers into different groups based on their purchasing behavior).
# *   **Association Rule Mining:** Discovering relationships between items in a dataset (e.g., "customers who buy bread also tend to buy milk"). This is often used in market basket analysis.
# *   **Regression:** Predicting a continuous numerical value (e.g., predicting the price of a house based on its features).
# *   **Anomaly Detection (Outlier Detection):** Identifying data points that deviate significantly from the norm (e.g., detecting fraudulent transactions).
# *   **Sequential Pattern Mining:** Discovering patterns that occur in a sequence over time (e.g., identifying common user navigation paths on a website).
#
# **Why is Data Mining Important?**
#
# Data mining is crucial for businesses and organizations because it enables them to:
#
# *   **Make Better Decisions:** By understanding customer behavior, market trends, and operational efficiencies, organizations can make more informed and strategic decisions.
# *   **Improve Customer Relationships:** Identifying customer preferences and predicting their needs allows for personalized marketing, better customer service, and increased loyalty.
# *   **Detect Fraud and Risk:** Anomaly detection can help identify fraudulent activities, security breaches, and potential risks.
# *   **Optimize Operations:** Understanding patterns in operational data can lead to improved efficiency, reduced costs, and better resource allocation.
# *   **Drive Innovation:** Discovering new insights can spark new product development, service offerings, and business models.
# *   **Gain a Competitive Advantage:** Organizations that effectively leverage data mining can outperform their competitors by understanding their market and customers better.
#
# In essence, data mining is a powerful tool for transforming raw data into valuable intelligence, driving progress and innovation across various fields.

# %% [markdown]
# ---
# ##### <a id='toc1_5_5_1_1_'></a>[**>>> Exercise 1 (Take home):**](#toc0_)
#
# `With your own prompt`, run the previous example in the following way:
#
# 1. Run it with the same model as the example (gemini-2.5-flash-lite).
# 2. Run it with a different gemini model from the available options for the API.
# 3. Discuss the differences on the results with different models.
# 4. Discuss what would happen if you change the system prompt.

# %%
from IPython.display import display, Markdown

# 1. Run with the same model
prompt = [
    "In ~150 words, explain the key differences between k-means and DBSCAN to a data-mining student. "
    "Include two short real-world example for each."
]
same_model = "gemini-2.5-flash-lite"
text_response_1, logs_1 = prompt_gemini(
    input_prompt=prompt, model_name=same_model, with_tokens_info=True
)

print("\n 1. gemini-2.5-flash-lite")
display(Markdown(text_response_1))
print("TOKENS:", logs_1)

# 2. Run with a different gemini model
other_model = "gemini-2.5-flash"
text_response_2, logs_2 = prompt_gemini(
    input_prompt=prompt, model_name=other_model, with_tokens_info=True
)

print("\n 2. gemini-2.5-flash")
display(Markdown(text_response_2))
print("TOKENS:", logs_2)

#Discussion
"""
3. Discuss the differences on the results with different models.
When comparing gemini-2.5-flash-lite and gemini-2.5-flash, both models correctly explained the differences between K-means and DBSCAN, but their styles varied. 
Flash-lite produced a clear, student-friendly summary with bullet points and simple examples, while Flash offered a more detailed, 
technical explanation that mentioned specific parameters such as eps and min_samples. 
This shows that Flash focuses more on analytical precision, while Flash-lite prioritizes readability and brevity.

4. Discuss what would happen if you change the system prompt.
If the system prompt were changed, the model's tone and structure would shift accordingly.
For example, if I give it a character such as "You are a concise TA" prompt, it would yield shorter, list-based answers, 
while "You are a creative educator" prompt would generate more analogies and narrative explanations. 
The content remains factually consistent, but the communication style and depth of detail adapt to the new role defined by the prompt.
"""
# Out:
#  1. gemini-2.5-flash-lite
# K-means and DBSCAN are both clustering algorithms, but they differ fundamentally in how they define and find clusters.
#
# **K-means** is a **centroid-based** algorithm. It aims to partition data into *k* clusters, where *k* is a pre-defined number. It works by iteratively assigning data points to the nearest centroid and then recalculating the centroids based on the mean of assigned points. K-means assumes clusters are spherical and of similar size.
#
# *   **Example 1:** Segmenting customers into *k* groups based on purchasing behavior for targeted marketing.
# *   **Example 2:** Grouping images into *k* categories based on visual features.
#
# **DBSCAN** (Density-Based Spatial Clustering of Applications with Noise) is a **density-based** algorithm. It identifies clusters as dense regions separated by sparser areas. It doesn't require specifying the number of clusters beforehand and can discover arbitrarily shaped clusters while identifying outliers (noise).
#
# *   **Example 1:** Identifying geographical areas with high crime rates (clusters) amidst less populated regions.
# *   **Example 2:** Detecting fraudulent transactions (clusters) in financial data, which often appear as dense, unusual patterns.
# TOKENS: {'model': 'gemini-2.5-flash-lite', 'input_tokens': 42, 'output_tokens': 253}
#
#  2. gemini-2.5-flash
# K-means and DBSCAN are distinct clustering algorithms. **K-means** is centroid-based, requiring you to pre-define 'k' (number of clusters). It assumes spherical, similarly sized clusters and assigns every point to one. K-means is sensitive to outliers, which can skew cluster centers.
# *   **Examples:**
#     1.  Segmenting customers into 3 distinct groups (e.g., "high-value," "mid-tier," "occasional").
#     2.  Grouping similar colors in an image for palette reduction.
#
# **DBSCAN** is density-based and doesn't require 'k'. It identifies clusters as dense regions separated by sparser areas, naturally labeling outliers as "noise." This allows it to discover arbitrarily shaped clusters. DBSCAN needs `eps` (neighborhood radius) and `min_samples` (density threshold) parameters.
# *   **Examples:**
#     1.  Detecting fraudulent transactions as noise points in financial data.
#     2.  Identifying geographic "hot spots" of crime without knowing the number of areas.
# TOKENS: {'model': 'gemini-2.5-flash', 'input_tokens': 42, 'output_tokens': 226}

# %% [markdown]
# ---
# ### <a id='toc1_5_6_'></a>[**2.2 Structured Output**](#toc0_)
#
# By default, an LLM responds with unstructured, free-form text. For data mining, this is often impractical, as we need data in a predictable format to load into tools like a pandas DataFrame for analysis. **Structured output** is a powerful feature that forces the model to return its response in a specific, machine-readable format, such as JSON.
#
# The key to enabling this is to provide the model with a **response schema**. This schema acts as a strict template or blueprint that the model's output must conform to. Instead of generating a paragraph, the model will fill in the fields defined in your schema with the relevant information it extracts from the prompt.
#
# In the following code, we define this schema using Python classes. Think of each class as defining a JSON object:
# *   The **attributes** of the class (e.g., `topic_name`, `sub_title`) become the keys in the final JSON object.
# *   The **type hints** for those attributes (e.g., `str`, `list`) tell the model what kind of data is expected for each key's value.
#
# We can even nest these classes inside one another to create complex, hierarchical JSON structures. This allows us to precisely control the format of the output, transforming the LLM from a simple text generator into a reliable tool for automated and structured data extraction.
#
# [Gemini's Structured Output Documentation](https://ai.google.dev/gemini-api/docs/structured-output)
#
# For data validation of schemas Gemini API uses the Pydantic library, for more documentation on it you can check: [Pydantic](https://docs.pydantic.dev/latest/)
#
# [JSON Format Documentation](https://docs.python.org/3/library/json.html)

# %%
from pydantic import BaseModel

# We define our structure schema that Gemini should follow for the output response

# Subsections on the topics we query
class Subsection(BaseModel):
    sub_title: str
    sub_explanation: str

# The top-level structure for the entire topic analysis
class Topic(BaseModel):
    topic_name: str
    subsections: list[Subsection]

# %%
input_prompt = ["Explain what are machine learning, data centers, llms and how do they relate to each other."]
text_response = prompt_gemini(input_prompt = input_prompt, schema = list[Topic])
print(text_response)
# Out:
# [
#   {
#     "topic_name": "Machine Learning",
#     "subsections": [
#       {
#         "sub_title": "Definition",
#         "sub_explanation": "Machine learning (ML) is a subset of artificial intelligence (AI) that focuses on building systems that can learn from and make decisions based on data. Instead of being explicitly programmed, ML algorithms use statistical techniques to enable systems to 'learn' from data, identify patterns, and make predictions or decisions with minimal human intervention."
#       },
#       {
#         "sub_title": "Types of Machine Learning",
#         "sub_explanation": "Common types include supervised learning (learning from labeled data), unsupervised learning (finding patterns in unlabeled data), and reinforcement learning (learning through trial and error with rewards and penalties)."
#       },
#       {
#         "sub_title": "Applications",
#         "sub_explanation": "ML is used in a wide range of applications, such as image recognition, natural language processing, recommendation systems, fraud detection, and medical diagnosis."
#       }
#     ]
#   },
#   {
#     "topic_name": "Data Centers",
#     "subsections": [
#       {
#         "sub_title": "Definition",
#         "sub_explanation": "A data center is a centralized facility that organizations use to house their critical applications and data. It typically consists of IT infrastructure, including servers, storage systems, networking equipment, and the supporting infrastructure such as power, cooling, and security systems."
#       },
#       {
#         "sub_title": "Purpose",
#         "sub_explanation": "Data centers are essential for storing, processing, and disseminating data. They provide the physical infrastructure required for digital operations, ensuring data availability, security, and performance."
#       },
#       {
#         "sub_title": "Scalability and Reliability",
#         "sub_explanation": "Modern data centers are designed to be scalable to accommodate growing data needs and reliable to ensure continuous operation and data protection."
#       }
#     ]
#   },
#   {
#     "topic_name": "Large Language Models (LLMs)",
#     "subsections": [
#       {
#         "sub_title": "Definition",
#         "sub_explanation": "Large Language Models (LLMs) are a type of artificial intelligence model that uses deep learning techniques, particularly transformer architectures, to understand, generate, and process human language. They are trained on massive amounts of text data, enabling them to perform a wide variety of natural language tasks."
#       },
#       {
#         "sub_title": "Capabilities",
#         "sub_explanation": "LLMs can perform tasks such as text generation, translation, summarization, question answering, and even code generation. Their 'large' nature refers to the vast number of parameters they contain and the enormous datasets they are trained on."
#       },
#       {
#         "sub_title": "Training and Inference",
#         "sub_explanation": "Training LLMs requires significant computational resources, and running them (inference) also demands substantial processing power."
#       }
#     ]
#   },
#   {
#     "topic_name": "Relationship Between Machine Learning, Data Centers, and LLMs",
#     "subsections": [
#       {
#         "sub_title": "LLMs as a Product of Machine Learning",
#         "sub_explanation": "LLMs are a sophisticated application and outcome of machine learning research and development. They leverage advanced ML algorithms and architectures to achieve their language processing capabilities."
#       },
#       {
#         "sub_title": "Data Centers as the Foundation for LLMs and ML",
#         "sub_explanation": "The training and deployment of LLMs, as well as many other ML models, are computationally intensive. Data centers provide the necessary high-performance computing infrastructure (powerful GPUs, CPUs, vast storage, and high-speed networking) required to handle the massive datasets and complex calculations involved in training and running these models."
#       },
#       {
#         "sub_title": "Interdependence",
#         "sub_explanation": "In essence, machine learning is the field that enables the creation of intelligent systems like LLMs. Data centers are the physical infrastructure that powers these computationally demanding ML processes, including the development and operation of LLMs. LLMs, in turn, are a powerful manifestation of what can be achieved with advanced machine learning, often hosted and run within data centers."
#       }
#     ]
#   }
# ]

# %%
import json

# Now the response can be parsed to a python object using the JSON dictionary structure loading
structured_resp = json.loads(text_response)
print(structured_resp)
print(type(structured_resp))
# Out:
# [{'topic_name': 'Machine Learning', 'subsections': [{'sub_title': 'Definition', 'sub_explanation': "Machine learning (ML) is a subset of artificial intelligence (AI) that focuses on building systems that can learn from and make decisions based on data. Instead of being explicitly programmed, ML algorithms use statistical techniques to enable systems to 'learn' from data, identify patterns, and make predictions or decisions with minimal human intervention."}, {'sub_title': 'Types of Machine Learning', 'sub_explanation': 'Common types include supervised learning (learning from labeled data), unsupervised learning (finding patterns in unlabeled data), and reinforcement learning (learning through trial and error with rewards and penalties).'}, {'sub_title': 'Applications', 'sub_explanation': 'ML is used in a wide range of applications, such as image recognition, natural language processing, recommendation systems, fraud detection, and medical diagnosis.'}]}, {'topic_name': 'Data Centers', 'subsections': [{'sub_title': 'Definition', 'sub_explanation': 'A data center is a centralized facility that organizations use to house their critical applications and data. It typically consists of IT infrastructure, including servers, storage systems, networking equipment, and the supporting infrastructure such as power, cooling, and security systems.'}, {'sub_title': 'Purpose', 'sub_explanation': 'Data centers are essential for storing, processing, and disseminating data. They provide the physical infrastructure required for digital operations, ensuring data availability, security, and performance.'}, {'sub_title': 'Scalability and Reliability', 'sub_explanation': 'Modern data centers are designed to be scalable to accommodate growing data needs and reliable to ensure continuous operation and data protection.'}]}, {'topic_name': 'Large Language Models (LLMs)', 'subsections': [{'sub_title': 'Definition', 'sub_explanation': 'Large Language Models (LLMs) are a type of artificial intelligence model that uses deep learning techniques, particularly transformer architectures, to understand, generate, and process human language. They are trained on massive amounts of text data, enabling them to perform a wide variety of natural language tasks.'}, {'sub_title': 'Capabilities', 'sub_explanation': "LLMs can perform tasks such as text generation, translation, summarization, question answering, and even code generation. Their 'large' nature refers to the vast number of parameters they contain and the enormous datasets they are trained on."}, {'sub_title': 'Training and Inference', 'sub_explanation': 'Training LLMs requires significant computational resources, and running them (inference) also demands substantial processing power.'}]}, {'topic_name': 'Relationship Between Machine Learning, Data Centers, and LLMs', 'subsections': [{'sub_title': 'LLMs as a Product of Machine Learning', 'sub_explanation': 'LLMs are a sophisticated application and outcome of machine learning research and development. They leverage advanced ML algorithms and architectures to achieve their language processing capabilities.'}, {'sub_title': 'Data Centers as the Foundation for LLMs and ML', 'sub_explanation': 'The training and deployment of LLMs, as well as many other ML models, are computationally intensive. Data centers provide the necessary high-performance computing infrastructure (powerful GPUs, CPUs, vast storage, and high-speed networking) required to handle the massive datasets and complex calculations involved in training and running these models.'}, {'sub_title': 'Interdependence', 'sub_explanation': 'In essence, machine learning is the field that enables the creation of intelligent systems like LLMs. Data centers are the physical infrastructure that powers these computationally demanding ML processes, including the development and operation of LLMs. LLMs, in turn, are a powerful manifestation of what can be achieved with advanced machine learning, often hosted and run wi ...
# <class 'list'>

# %%
# So now we have an object that we can explore/use in a pythonic way for our purposes
for topic in structured_resp:
    print(topic["topic_name"], "\n")
    # We can access each subsection as well
    for subsection in topic["subsections"]:
        print("\t", subsection["sub_title"], "\n")
        print("\t\t", subsection["sub_explanation"], "\n")
# Out:
# Machine Learning
#
# 	 Definition
#
# 		 Machine learning (ML) is a subset of artificial intelligence (AI) that focuses on building systems that can learn from and make decisions based on data. Instead of being explicitly programmed, ML algorithms use statistical techniques to enable systems to 'learn' from data, identify patterns, and make predictions or decisions with minimal human intervention.
#
# 	 Types of Machine Learning
#
# 		 Common types include supervised learning (learning from labeled data), unsupervised learning (finding patterns in unlabeled data), and reinforcement learning (learning through trial and error with rewards and penalties).
#
# 	 Applications
#
# 		 ML is used in a wide range of applications, such as image recognition, natural language processing, recommendation systems, fraud detection, and medical diagnosis.
#
# Data Centers
#
# 	 Definition
#
# 		 A data center is a centralized facility that organizations use to house their critical applications and data. It typically consists of IT infrastructure, including servers, storage systems, networking equipment, and the supporting infrastructure such as power, cooling, and security systems.
#
# 	 Purpose
#
# 		 Data centers are essential for storing, processing, and disseminating data. They provide the physical infrastructure required for digital operations, ensuring data availability, security, and performance.
#
# 	 Scalability and Reliability
#
# 		 Modern data centers are designed to be scalable to accommodate growing data needs and reliable to ensure continuous operation and data protection.
#
# Large Language Models (LLMs)
#
# 	 Definition
#
# 		 Large Language Models (LLMs) are a type of artificial intelligence model that uses deep learning techniques, particularly transformer architectures, to understand, generate, and process human language. They are trained on massive amounts of text data, enabling them to perform a wide variety of natural language tasks.
#
# 	 Capabilities
#
# 		 LLMs can perform tasks such as text generation, translation, summarization, question answering, and even code generation. Their 'large' nature refers to the vast number of parameters they contain and the enormous datasets they are trained on.
#
# 	 Training and Inference
#
# 		 Training LLMs requires significant computational resources, and running them (inference) also demands substantial processing power.
#
# Relationship Between Machine Learning, Data Centers, and LLMs
#
# 	 LLMs as a Product of Machine Learning
#
# 		 LLMs are a sophisticated application and outcome of machine learning research and development. They leverage advanced ML algorithms and architectures to achieve their language processing capabilities.
#
# 	 Data Centers as the Foundation for LLMs and ML
#
# 		 The training and deployment of LLMs, as well as many other ML models, are computationally intensive. Data centers provide the necessary high-performance computing infrastructure (powerful GPUs, CPUs, vast storage, and high-speed networking) required to handle the massive datasets and complex calculations involved in training and running these models.
#
# 	 Interdependence
#
# 		 In essence, machine learning is the field that enables the creation of intelligent systems like LLMs. Data centers are the physical infrastructure that powers these computationally demanding ML processes, including the development and operation of LLMs. LLMs, in turn, are a powerful manifestation of what can be achieved with advanced machine learning, often hosted and run within data centers.

# %% [markdown]
# ##### <a id='toc1_5_6_1_1_'></a>[**>>> Exercise 2 (Take home):**](#toc0_)
#
# Try a prompt with your own schema structure, it needs to be completely different to the example. It should show an intuitive way to represent the text output of the model based on the prompt you chose. See the documentation for reference: https://ai.google.dev/gemini-api/docs/structured-output

# %%
from pydantic import BaseModel
from typing import List
import json

# my own new schema structure for analyzing the song
class Emotion(BaseModel):
    emotion_name: str
    intensity: int

class SongAnalysis(BaseModel):
    song_title: str
    artist: str
    main_theme: str
    emotions: List[Emotion]
    summary: str
    audience_suggestion: str

# prompt
input_prompt = [
    "Analyze the song 'Love Story' by Taylor Swift. "
    "Explain its main theme, emotional tone (list 2-3 emotions with intensity 1-10), "
    "give a short 2-sentence summary, and recommend what type of audience might enjoy it."
]

text_response = prompt_gemini(
    input_prompt=input_prompt, schema=SongAnalysis, model_name="gemini-2.5-flash-lite"
)

# turn into Python structrual data
structured_resp = json.loads(text_response)
print("Song:", structured_resp["song_title"])
print("Artist:", structured_resp["artist"])
print("Theme:", structured_resp["main_theme"])
print("Emotions:")
for emo in structured_resp["emotions"]:
    print(f"  - {emo['emotion_name']}: intensity {emo['intensity']}")
print("Summary:", structured_resp["summary"])
print("Suggestion:", structured_resp["audience_suggestion"])
# Out:
# Song: Love Story
# Artist: Taylor Swift
# Theme: A modern retelling of Romeo and Juliet, focusing on overcoming obstacles to be together.
# Emotions:
#   - Hopeful: intensity 8
#   - Romantic: intensity 9
#   - Determined: intensity 7
# Summary: This song narrates a fairytale romance where the protagonist defies her father's disapproval to be with the one she loves. It culminates in a proposal, offering a happy ending to a classic tale of forbidden love.
# Suggestion: Fans of romantic pop music, young adults, and those who enjoy fairytale narratives will likely appreciate this song.

# %% [markdown]
# ---
# ### <a id='toc1_5_7_'></a>[**2.3 Information Extraction and Grounding:**](#toc0_)
#
# `NOTE: This whole section including the exercise is now considered a bonus section, not counted for the main grade.`
#
# When using LLMs to extract structured data from text, two main challenges arise:
#
# 1.  **Trust:** LLMs can "hallucinate" or invent information. We need to ensure the extracted data is accurate and comes directly from the source text.
# 2.  **Scalability:** We need a reliable way to extract complex information consistently from thousands of large, messy documents.
#
# The solution to these challenges is **grounding**—the process of linking every piece of extracted data back to its specific origin in the source document. This creates a verifiable audit trail, building trust in the output.

# %% [markdown]
# ---
# #### <a id='toc1_5_7_1_'></a>[**`langextract`: A Library for Grounded Extraction**](#toc0_)
#
# **`langextract`** is an open-source Python library from Google designed to create trustworthy data extraction pipelines. It uses LLMs to convert unstructured text into structured data with a focus on reliability and traceability.
#
# **Key Features:**
#
# *   **Precise Grounding:** Its core feature. It maps every extracted item to its exact character position in the original text, allowing for easy verification.
# *   **Reliable Structured Output:** Uses examples (few-shot prompting) to ensure the LLM's output consistently follows a predefined format.
# *   **Adaptable & No Fine-Tuning:** Can be adapted to any domain (e.g., legal, medical) simply by changing the examples and instructions, without needing to retrain a model.
# *   **Handles Long Documents:** Built to process lengthy texts that might exceed an LLM's standard context window.
# *   **Flexible LLM Support:** It is model-agnostic and works with various LLMs like Gemini, OpenAI models, and even local open-source models through Ollama.
#
# **`Github repository:`** [langextract](https://github.com/google/langextract)

# %% [markdown]
# ---
#
# ##### <a id='toc1_5_7_1_1_'></a>[**2.3.1 Using PDF Documents:**](#toc0_)
#
# For PDF Document information extraction we are going to use the `pymupdf` library. Documentation: [pymupdf](https://pymupdf.readthedocs.io/en/latest/)
#
# And then we are going to pass it on to langextract to get insights on the document's content.
#
# We can also process documents using Gemini, for more information you can check their documentation: [Document Understanding](https://ai.google.dev/gemini-api/docs/document-processing)

# %%
import pymupdf
# Extract text from the PDF and format it for the prompt
# This is a review from the movie interstellar
pdf_path = "./data/documents/doc_example_review_interstellar.pdf"
formatted_text = ""
try:
    doc = pymupdf.open(pdf_path)
    # In case the PDF documents have more than one page, in this example it only has one
    for i, page in enumerate(doc):
        text = page.get_text("text")
        # Format follows the prompt's requirement: **Page X** """document's text"""
        formatted_text += f'**Page {i + 1}**\n'
        formatted_text += f'"""\n{text.strip()}\n"""\n\n'
    doc.close()
    print(f"✓ Extracted text from '{pdf_path}'")
except Exception as e:
    print(f"Could not read PDF: {e}")
    formatted_text = "Error: Could not process PDF file."
# Out:
# ✓ Extracted text from './data/documents/doc_example_review_interstellar.pdf'

# %%
print(formatted_text)
# Out:
# **Page 1**
# """
# Dan Baldwin
# Group 4
# Auteur Review - Interstellar
# I believe Christopher Nolan: the director behind the 2014 sci-ﬁ/adventure cinematic ‘Interstellar,’
# to be a very intellectual and imaginative inventive talent.
# His style in his previous ﬁlms sets characters in epic unique locations, with gargantuan issues to
# face, and artistically impresses the audience with how the characters solve their problems. For
# example, in Nolan’s 2010 ﬁlm ‘Inception,’ he tackles the idea of dreams, and sets his characters
# diving through dreams within dreams within even more dreams to complete their goals. Because
# this idea is so farfetched, and dreams are a subject in which science has made little factual
# discovery in, Nolan is free to use his creativity to present ideas such as landscapes folding in on
# themselves and corridors spinning, without seeming unrealistic.
# This brain-racking epic theme is once again evident in ‘Interstellar,’ as Nolan sets his characters
# during a second American dust bowl on future Earth. The world is short of food, and will soon be
# uninhabitable. So, ex-NASA pilot ‘Cooper’ (Matthew McConaughey) is summoned back to space
# travel in a bid to ﬁnd a new planet for the species to inhabit. Luckily for Cooper and his team, a
# black hole orbiting Saturn can transport them further into space to land on these potential
# planets.
# Throughout the ﬂick, the crew explore multiple worlds - again feeding Nolan’s mind more
# opportunities to create crazy scenarios. For example, one planet that Cooper and his friends,
# ‘Brand,’ (Anne Hathaway) and ‘Romilly,’ (David Gyasi) visit initially seems like an inﬁnite sea of two
# feet deep water. Not threatening at all right? Well think again, because the crew suddenly ﬁnd out
# that a giant 100ft tidal wave is about to hit them, and they have minutes to ﬂy away. Nolan further
# increases the stakes in this scene as it is explained that every hour spent on this planet counts for
# seven years on earth, meaning the planet will be destroyed before they return if their ship sinks.
# At the climax of the ﬁlm, the crew end up sending themselves through a black hole into a
# tesseract (a 3D representation of a larger dimension) to ﬁnd the ‘secret to harnessing gravity’
# which will let the human race bend space-time in order to survive oﬀ earth. I know. Mental.
# The imagination that Nolan possesses and implicates into ‘Interstellar’ is farfetched and
# wonderful, not only impressing his audience with the appealing visuals he creates, but induces
# them to think and discuss what is going on due its scientiﬁc depth. Personally, as someone who is
# bamboozled by the idea of how big the universe is, I ﬁnd it unendingly entertaining to repeatedly
# watch this ﬁlm and understanding it more each time, and can only hope the technology portrayed
# will one day come true.
# Overall, ‘Interstellar’ is a clear example of Nolan’s auteur talent, as he once again ﬁgments yet
# another cluster of conditions for us to marvel at. With a fantastic score from world famous
# composer Hanz Zimmer, his epic, orchestral theme sets the audience in the palm of his hands as
# we stress over how we are all going to be saved once again.
# """

# %% [markdown]
# We define our prompt and examples based on our required type of data, in this case we are going to do it having `movie reviews` in mind.

# %%
import langextract as lx
import textwrap

# Defining the extraction prompt for "movie review" type of data
prompt = textwrap.dedent("""\
    Extract specific opinions and their impact on the audience from this movie review.
    Important: Use exact text verbatim from the input for extraction_text. Do not paraphrase.
    Extract entities in order of appearance with no overlapping text spans.

    Use the 'opinion_statement' class for direct judgments about film elements (like plot, score, or acting).
    - 'subject' should be the element being reviewed.
    - 'sentiment' should be Positive, Negative, or Neutral.
    - 'key_phrase' should be the core descriptive words.

    Use the 'audience_impact' class for phrases describing the effect on the viewer.
    - 'emotion_evoked' should be the feeling or reaction (e.g., stress, joy, confusion).
    - 'causal_element' is what part of the film caused the reaction.
    - 'target_audience' is who was affected (e.g., 'the audience', 'the reviewer').
    """)

# Providing high-quality examples to guide the model
# These examples show the model exactly how to differentiate between the two classes
examples = [
    # Example 1: Demonstrates a positive opinion on the plot and its direct impact on the reviewer
    lx.data.ExampleData(
        text="The film boasts a truly clever plot that kept me guessing until the very end.",
        extractions=[
            lx.data.Extraction(
                extraction_class="opinion_statement",
                extraction_text="a truly clever plot",
                attributes={
                    "subject": "The plot",
                    "sentiment": "Positive",
                    "key_phrase": "truly clever"
                }
            ),
            lx.data.Extraction(
                extraction_class="audience_impact",
                extraction_text="kept me guessing until the very end",
                attributes={
                    "emotion_evoked": ["engaged", "curious"],
                    "causal_element": "The plot",
                    "target_audience": "the reviewer"
                }
            ),
        ]
    ),
    # Example 2: Shows a negative opinion and a separate audience impact caused by the soundtrack
    lx.data.ExampleData(
        text="Unfortunately, the dialogue felt clunky and unnatural, and the jarring soundtrack made the audience jump.",
        extractions=[
            lx.data.Extraction(
                extraction_class="opinion_statement",
                extraction_text="the dialogue felt clunky and unnatural",
                attributes={
                    "subject": "The dialogue",
                    "sentiment": "Negative",
                    "key_phrase": "clunky and unnatural"
                }
            ),
            lx.data.Extraction(
                extraction_class="audience_impact",
                extraction_text="made the audience jump",
                attributes={
                    "emotion_evoked": ["startled", "on edge"],
                    "causal_element": "The soundtrack",
                    "target_audience": "the audience"
                }
            )
        ]
    )
]

# %% [markdown]
# Here we define our main function to call for langextract information extraction, note that there are some constants in the functions that we are not going to change for the example but it would be required to explore and understand in the exercise. In this function we obtain the resulting raw extracted information into a .jsonl file and the visualization into a .html file. Check the documentation for more information.
#
# The files will be saved in the following directory: `results/info_extractions`

# %%
import os
import langextract as lx

# We define our main langextract function 
def grounded_info_extraction(input_documents, prompt, examples, file_name, model_id ="gemini-2.5-flash-lite", extraction_passes = 1, max_workers = 5, max_char_buffer = 2000):
    result = lx.extract(
        text_or_documents=input_documents,
        prompt_description=prompt,
        examples=examples,
        model_id=model_id,
        extraction_passes=extraction_passes,    # Improves recall through multiple passes over the same text, needs temperature above 0.0
        max_workers=max_workers,         # Parallel processing for speed, remember there are API call rate limits, so do not abuse
        max_char_buffer=max_char_buffer    # Smaller contexts for better accuracy, currently: 1000 characters per batch
    )

    # Display results
    print(f"Extracted {len(result.extractions)} entities:\n")
    for extraction in result.extractions:
        print(f"• {extraction.extraction_class}: '{extraction.extraction_text}'")
        if extraction.attributes:
            for key, value in extraction.attributes.items():
                print(f"  - {key}: {value}")
    
    output_dir = "./results/info_extractions"
    os.makedirs(output_dir, exist_ok=True)
    # Save results to JSONL
    lx.io.save_annotated_documents([result], output_name=f"{file_name}.jsonl", output_dir=output_dir)

    # Generate interactive visualization
    html_content = lx.visualize(f"{output_dir}/{file_name}.jsonl")
    with open(f"{output_dir}/{file_name}_vis.html", "w") as f:
        if hasattr(html_content, 'data'):
            f.write(html_content.data)
        else:
            f.write(html_content)

    print(f"✓ Visualization saved to {output_dir}/{file_name}_vis.html")
    
    # returning html content for display
    return html_content

# %%
html_content = grounded_info_extraction(formatted_text, prompt, examples, "review_extraction_example")
# Out:
# WARNING:google_genai._api_client:Both GOOGLE_API_KEY and GEMINI_API_KEY are set. Using GOOGLE_API_KEY.
# Extracted 13 entities:
#
# • opinion_statement: 'a very intellectual and imaginative inventive talent'
#   - subject: Christopher Nolan
#   - sentiment: Positive
#   - key_phrase: very intellectual and imaginative inventive talent
# • opinion_statement: 'artistically impresses the audience'
#   - subject: Nolan's style
#   - sentiment: Positive
#   - key_phrase: artistically impresses
# • opinion_statement: 'This brain-racking epic theme is once again evident in ‘Interstellar,’'
#   - subject: The theme
#   - sentiment: Positive
#   - key_phrase: brain-racking epic theme
# • opinion_statement: 'crazy scenarios'
#   - subject: Nolan's mind
#   - sentiment: Positive
#   - key_phrase: crazy
# • opinion_statement: 'Not threatening at all right?'
#   - subject: The planet
#   - sentiment: Neutral
#   - key_phrase: Not threatening at all
# • opinion_statement: 'a giant 100ft tidal wave is about to hit them'
#   - subject: The tidal wave
#   - sentiment: Negative
#   - key_phrase: giant 100ft tidal wave
# • audience_impact: 'minutes to ﬂy away'
#   - emotion_evoked: ['stress', 'urgency']
#   - causal_element: The tidal wave
#   - target_audience: the crew
# • opinion_statement: 'farfetched and wonderful'
#   - subject: The imagination that Nolan possesses and implicates into ‘Interstellar’
#   - sentiment: Positive
#   - key_phrase: farfetched and wonderful
# • audience_impact: 'not only impressing his audience with the appealing visuals he creates, but induces them to think and discuss what is going on due its scientiﬁc depth'
#   - emotion_evoked: ['impressed', 'thoughtful', 'engaged']
#   - causal_element: The appealing visuals and scientific depth
#   - target_audience: his audience
# • audience_impact: 'I ﬁnd it unendingly entertaining to repeatedly watch this ﬁlm and understanding it more each time'
#   - emotion_evoked: ['entertained', 'intellectually stimulated']
#   - causal_element: The film's complexity and depth
#   - target_audience: the reviewer
# • opinion_statement: 'a clear example of Nolan’s auteur talent'
#   - subject: ‘Interstellar’
#   - sentiment: Positive
#   - key_phrase: clear example of Nolan’s auteur talent
# • opinion_statement: 'fantastic score'
#   - subject: The score
#   - sentiment: Positive
#   - key_phrase: fantastic
# • audience_impact: 'sets the audience in the palm of his hands as we stress over how we are all going to be saved once again'
#   - emotion_evoked: ['captivated', 'stressed']
#   - causal_element: His epic, orchestral theme
#   - target_audience: the audience
# LangExtract: Saving to review_extraction_example.jsonl: 1 docs [00:00, 475.98 docs/s]
# ✓ Saved 1 documents to review_extraction_example.jsonl
# LangExtract: Loading review_extraction_example.jsonl: 100%|██████████| 8.58k/8.58k [00:00<00:00, 9.07MB/s]
# ✓ Loaded 1 documents from review_extraction_example.jsonl
# ✓ Visualization saved to ./results/info_extractions/review_extraction_example_vis.html

# %%
import json
# We can also observe the structure of the raw extracted data
with open("./results/info_extractions/review_extraction_example.jsonl", "r") as f:
    content_extracted_raw = json.load(f)
content_extracted_raw
# Out:
# {'extractions': [{'extraction_class': 'opinion_statement',
#    'extraction_text': 'a very intellectual and imaginative inventive talent',
#    'char_interval': {'start_pos': 172, 'end_pos': 224},
#    'alignment_status': 'match_exact',
#    'extraction_index': 1,
#    'group_index': 0,
#    'description': None,
#    'attributes': {'subject': 'Christopher Nolan',
#     'sentiment': 'Positive',
#     'key_phrase': 'very intellectual and imaginative inventive talent'}},
#   {'extraction_class': 'opinion_statement',
#    'extraction_text': 'artistically impresses the audience',
#    'char_interval': {'start_pos': 338, 'end_pos': 373},
#    'alignment_status': 'match_exact',
#    'extraction_index': 2,
#    'group_index': 1,
#    'description': None,
#    'attributes': {'subject': "Nolan's style",
#     'sentiment': 'Positive',
#     'key_phrase': 'artistically impresses'}},
#   {'extraction_class': 'opinion_statement',
#    'extraction_text': 'This brain-racking epic theme is once again evident in ‘Interstellar,’',
#    'char_interval': {'start_pos': 878, 'end_pos': 948},
#    'alignment_status': 'match_exact',
#    'extraction_index': 3,
#    'group_index': 2,
#    'description': None,
#    'attributes': {'subject': 'The theme',
#     'sentiment': 'Positive',
#     'key_phrase': 'brain-racking epic theme'}},
#   {'extraction_class': 'opinion_statement',
#    'extraction_text': 'crazy scenarios',
#    'char_interval': {'start_pos': 1484, 'end_pos': 1499},
#    'alignment_status': 'match_exact',
#    'extraction_index': 4,
#    'group_index': 3,
#    'description': None,
#    'attributes': {'subject': "Nolan's mind",
#     'sentiment': 'Positive',
#     'key_phrase': 'crazy'}},
#   {'extraction_class': 'opinion_statement',
#    'extraction_text': 'Not threatening at all right?',
#    'char_interval': {'start_pos': 1676, 'end_pos': 1705},
#    'alignment_status': 'match_exact',
#    'extraction_index': 5,
#    'group_index': 4,
#    'description': None,
#    'attributes': {'subject': 'The planet',
#     'sentiment': 'Neutral',
#     'key_phrase': 'Not threatening at all'}},
#   {'extraction_class': 'opinion_statement',
#    'extraction_text': 'a giant 100ft tidal wave is about to hit them',
#    'char_interval': {'start_pos': 1764, 'end_pos': 1809},
#    'alignment_status': 'match_exact',
#    'extraction_index': 6,
#    'group_index': 5,
#    'description': None,
#    'attributes': {'subject': 'The tidal wave',
#     'sentiment': 'Negative',
#     'key_phrase': 'giant 100ft tidal wave'}},
#   {'extraction_class': 'audience_impact',
#    'extraction_text': 'minutes to ﬂy away',
#    'char_interval': {'start_pos': 1825, 'end_pos': 1843},
#    'alignment_status': 'match_exact',
#    'extraction_index': 7,
#    'group_index': 6,
#    'description': None,
#    'attributes': {'emotion_evoked': ['stress', 'urgency'],
#     'causal_element': 'The tidal wave',
#     'target_audience': 'the crew'}},
#   {'extraction_class': 'opinion_statement',
#    'extraction_text': 'farfetched and wonderful',
#    'char_interval': {'start_pos': 2418, 'end_pos': 2443},
#    'alignment_status': 'match_exact',
#    'extraction_index': 1,
#    'group_index': 0,
#    'description': None,
#    'attributes': {'subject': 'The imagination that Nolan possesses and implicates into ‘Interstellar’',
#     'sentiment': 'Positive',
#     'key_phrase': 'farfetched and wonderful'}},
#   {'extraction_class': 'audience_impact',
#    'extraction_text': 'not only impressing his audience with the appealing visuals he creates, but induces them to think and discuss what is going on due its scientiﬁc depth',
#    'char_interval': {'start_pos': 2445, 'end_pos': 2596},
#    'alignment_status': 'match_exact',
#    'extraction_index': 2,
#    'group_index': 1,
#    'description': None,
#    'attributes': {'emotion_evoked': ['impressed', 'thoughtful', 'engaged'],
#     'causal_element': 'The appealing visuals and scientific depth',
#     'target_audience': 'his audience'}},
#   {'extraction_class': 'audience_impact',
#    'extraction_text': 'I ﬁnd it unendingly entertaining to repeatedly watch this ﬁlm and understanding it more each time',
#    'char_interval': {'start_pos': 2680, 'end_pos': 2778},
#    'alignment_status': 'match_exact',
#    'extraction_index': 3,
#    'group_index': 2,
#    'description': None,
#    'attributes': {'emotion_evoked': ['entertained',
#      'intellectually stimulated'],
#     'causal_element': "The film's complexity and depth",
#     'target_audience': 'the reviewer'}},
#   {'extraction_class': 'opinion_statement',
#    'extraction_text': 'a clear example of Nolan’s auteur talent',
#    'char_interval': {'start_pos': 2876, 'end_pos': 2916},
#    'alignment_status': 'match_exact',
#    'extraction_index': 4,
#    'group_index': 3,
#    'description': None,
#    'attributes': {'subject': '‘Interstellar’',
#     'sentiment': 'Positive',
#     'key_phrase': 'clear example of Nolan’s auteur talent'}},
#   {'extraction_class': 'opinion_statement',
#    'extraction_text': 'fantastic score',
#    'char_interval': {'start_pos': 3006, 'end_pos': 3021},
#    'alignment_status': 'match_exact',
#    'extraction_index': 5,
#    'group_index': 4,
#    'description': None,
#    'attributes': {'subject': 'The score',
#     'sentiment': 'Positive',
#     'key_phrase': 'fantastic'}},
#   {'extraction_class': 'audience_impact',
#    'extraction_text': 'sets the audience in the palm of his hands as we stress over how we are all going to be saved once again',
#    'char_interval': {'start_pos': 3090, 'end_pos': 3195},
#    'alignment_status': 'match_exact',
#    'extraction_index': 6,
#    'group_index': 5,
#    'description': None,
#    'attributes': {'emotion_evoked': ['captivated', 'stressed'],
#     'causal_element': 'His epic, orchestral theme',
#     'target_audience': 'the audience'}}],
#  'text': '**Page 1**\n"""\nDan Baldwin\nGroup 4\nAuteur Review - Interstellar \nI believe Christopher Nolan: the director behind the 2014 sci-ﬁ/adventure cinematic ‘Interstellar,’ \nto be a very intellectual and imaginative inventive talent.  \nHis style in his previous ﬁlms sets characters in epic unique locations, with gargantuan issues to \nface, and artistically impresses the audience with how the characters solve their problems. For \nexample, in Nolan’s 2010 ﬁlm ‘Inception,’ he tackles the idea of dreams, and sets his characters \ndiving through dreams within dreams within even more dreams to complete their goals. Because \nthis idea is so farfetched, and dreams are a subject in which science has made little factual \ndiscovery in, Nolan is free to use his creativity to present ideas such as landscapes folding in on \nthemselves and corridors spinning, without seeming unrealistic. \nThis brain-racking epic theme is once again evident in ‘Interstellar,’ as Nolan sets his characters \nduring a second American dust bowl on future Earth. The world is short of food, and will soon be \nuninhabitable. So, ex-NASA pilot ‘Cooper’ (Matthew McConaughey) is summoned back to space \ntravel in a bid to ﬁnd a new planet for the species to inhabit. Luckily for Cooper and his team, a \nblack hole orbiting Saturn can transport them further into space to land on these potential \nplanets. \nThroughout the ﬂick, the crew explore multiple worlds - again feeding Nolan’s mind more \nopportunities to create crazy scenarios. For example, one planet that Cooper and his friends, \n‘Brand,’ (Anne Hathaway) and ‘Romilly,’ (David Gyasi) visit initially seems like an inﬁnite sea of two \nfeet deep water. Not threatening at all right? Well think again, because the crew suddenly ﬁnd out \nthat a giant 100ft tidal wave is about to hit them, and they have minutes to ﬂy away. Nolan further \nincreases the stakes in this scene as it is explained that every hour spent on this planet counts for \nseven years on earth, meaning the planet will be destroyed before they return if their ship sinks. \nAt the climax of the ﬁlm, the crew end up sending themselves through a black hole into a \ntesseract (a 3D representation of a larger dimension) to ﬁnd the ‘secret to harnessing gravity’ \nwhich will let the human race bend space-time in order to survive oﬀ earth. I know. Mental. \nThe imagination that Nolan possesses and implicates into ‘Interstellar’ is farfetched and \nwonderful, not only impressing his audience with the appealing visuals he creates, but induces \nthem to think and discuss what is going on due its scientiﬁc depth. Personally, as someone who is \nbamboozled by the idea of how big the universe is, I ﬁnd it unendingly entertaining to repeatedly \nwatch this ﬁlm and understanding it more each time, and can only hope the technology portrayed \nwill one day come true. \nOverall, ‘Interstellar’ is a clear example of Nolan’s auteur talent, as he once again ﬁgments yet \nanother cluster of conditions for us to marvel at. With a fantastic score from world famous \ncomposer Hanz Zimmer, his epic, orchestral theme sets the audience in the palm of his hands as \nwe stress over how we are all going to be saved once again.\n"""\n\n',
#  'document_id': 'doc_94df09d2'}

# %%
html_content
# Out:
# <style>
# .lx-highlight { position: relative; border-radius:3px; padding:1px 2px;}
# .lx-highlight .lx-tooltip {
#   visibility: hidden;
#   opacity: 0;
#   transition: opacity 0.2s ease-in-out;
#   background: #333;
#   color: #fff;
#   text-align: left;
#   border-radius: 4px;
#   padding: 6px 8px;
#   position: absolute;
#   z-index: 1000;
#   bottom: 125%;
#   left: 50%;
#   transform: translateX(-50%);
#   font-size: 12px;
#   max-width: 240px;
#   white-space: normal;
#   box-shadow: 0 2px 6px rgba(0,0,0,0.3);
# }
# .lx-highlight:hover .lx-tooltip { visibility: visible; opacity:1; }
# .lx-animated-wrapper { max-width: 100%; font-family: Arial, sans-serif; }
# .lx-controls {
#   background: #fafafa; border: 1px solid #90caf9; border-radius: 8px;
#   padding: 12px; margin-bottom: 16px;
# }
# .lx-button-row {
#   display: flex; justify-content: center; gap: 8px; margin-bottom: 12px;
# }
# .lx-control-btn {
#   background: #4285f4; color: white; border: none; border-radius: 4px;
#   padding: 8px 16px; cursor: pointer; font-size: 13px; font-weight: 500;
#   transition: background-color 0.2s;
# }
# .lx-control-btn:hover { background: #3367d6; }
# .lx-progress-container {
#   margin-bottom: 8px;
# }
# .lx-progress-slider {
#   width: 100%; margin: 0; appearance: none; height: 6px;
#   background: #ddd; border-radius: 3px; outline: none;
# }
# .lx-progress-slider::-webkit-slider-thumb {
#   appearance: none; width: 18px; height: 18px; background: #4285f4;
#   border-radius: 50%; cursor: pointer;
# }
# .lx-progress-slider::-moz-range-thumb {
#   width: 18px; height: 18px; background: #4285f4; border-radius: 50%;
#   cursor: pointer; border: none;
# }
# .lx-status-text {
#   text-align: center; font-size: 12px; color: #666; margin-top: 4px;
# }
# .lx-text-window {
#   font-family: monospace; white-space: pre-wrap; border: 1px solid #90caf9;
#   padding: 12px; max-height: 260px; overflow-y: auto; margin-bottom: 12px;
#   line-height: 1.6;
# }
# .lx-attributes-panel {
#   background: #fafafa; border: 1px solid #90caf9; border-radius: 6px;
#   padding: 8px 10px; margin-top: 8px; font-size: 13px;
# }
# .lx-current-highlight {
#   border-bottom: 4px solid #ff4444;
#   font-weight: bold;
#   animation: lx-pulse 1s ease-in-out;
# }
# @keyframes lx-pulse {
#   0% { text-decoration-color: #ff4444; }
#   50% { text-decoration-color: #ff0000; }
#   100% { text-decoration-color: #ff4444; }
# }
# .lx-legend {
#   font-size: 12px; margin-bottom: 8px;
#   padding-bottom: 8px; border-bottom: 1px solid #e0e0e0;
# }
# .lx-label {
#   display: inline-block;
#   padding: 2px 4px;
#   border-radius: 3px;
#   margin-right: 4px;
#   color: #000;
# }
# .lx-attr-key {
#   font-weight: 600;
#   color: #1565c0;
#   letter-spacing: 0.3px;
# }
# .lx-attr-value {
#   font-weight: 400;
#   opacity: 0.85;
#   letter-spacing: 0.2px;
# }
#
# /* Add optimizations with larger fonts and better readability for GIFs */
# .lx-gif-optimized .lx-text-window { font-size: 16px; line-height: 1.8; }
# .lx-gif-optimized .lx-attributes-panel { font-size: 15px; }
# .lx-gif-optimized .lx-current-highlight { text-decoration-thickness: 4px; }
# </style>
#     <div class="lx-animated-wrapper lx-gif-optimized">
#       <div class="lx-attributes-panel">
#         <div class="lx-legend">Highlights Legend: <span class="lx-label" style="background-color:#D2E3FC;">audience_impact</span> <span class="lx-label" style="background-color:#C8E6C9;">opinion_statement</span></div>
#         <div id="attributesContainer"></div>
#       </div>
#       <div class="lx-text-window" id="textWindow">
#         **Page 1**
# &quot;&quot;&quot;
# Dan Baldwin
# Group 4
# Auteur Review - Interstellar
# I believe Christopher Nolan: the director behind the 2014 sci-ﬁ/adventure cinematic ‘Interstellar,’
# to be <span class="lx-highlight lx-current-highlight" data-idx="0" style="background-color:#C8E6C9;">a very intellectual and imaginative inventive talent</span>.
# His style in his previous ﬁlms sets characters in epic unique locations, with gargantuan issues to
# face, and <span class="lx-highlight" data-idx="1" style="background-color:#C8E6C9;">artistically impresses the audience</span> with how the characters solve their problems. For
# example, in Nolan’s 2010 ﬁlm ‘Inception,’ he tackles the idea of dreams, and sets his characters
# diving through dreams within dreams within even more dreams to complete their goals. Because
# this idea is so farfetched, and dreams are a subject in which science has made little factual
# discovery in, Nolan is free to use his creativity to present ideas such as landscapes folding in on
# themselves and corridors spinning, without seeming unrealistic.
# <span class="lx-highlight" data-idx="2" style="background-color:#C8E6C9;">This brain-racking epic theme is once again evident in ‘Interstellar,’</span> as Nolan sets his characters
# during a second American dust bowl on future Earth. The world is short of food, and will soon be
# uninhabitable. So, ex-NASA pilot ‘Cooper’ (Matthew McConaughey) is summoned back to space
# travel in a bid to ﬁnd a new planet for the species to inhabit. Luckily for Cooper and his team, a
# black hole orbiting Saturn can transport them further into space to land on these potential
# planets.
# Throughout the ﬂick, the crew explore multiple worlds - again feeding Nolan’s mind more
# opportunities to create <span class="lx-highlight" data-idx="3" style="background-color:#C8E6C9;">crazy scenarios</span>. For example, one planet that Cooper and his friends,
# ‘Brand,’ (Anne Hathaway) and ‘Romilly,’ (David Gyasi) visit initially seems like an inﬁnite sea of two
# feet deep water. <span class="lx-highlight" data-idx="4" style="background-color:#C8E6C9;">Not threatening at all right?</span> Well think again, because the crew suddenly ﬁnd out
# that <span class="lx-highlight" data-idx="5" style="background-color:#C8E6C9;">a giant 100ft tidal wave is about to hit them</span>, and they have <span class="lx-highlight" data-idx="6" style="background-color:#D2E3FC;">minutes to ﬂy away</span>. Nolan further
# increases the stakes in this scene as it is explained that every hour spent on this planet counts for
# seven years on earth, meaning the planet will be destroyed before they return if their ship sinks.
# At the climax of the ﬁlm, the crew end up sending themselves through a black hole into a
# tesseract (a 3D representation of a larger dimension) to ﬁnd the ‘secret to harnessing gravity’
# which will let the human race bend space-time in order to survive oﬀ earth. I know. Mental.
# The imagination that Nolan possesses and implicates into ‘Interstellar’ is <span class="lx-highlight" data-idx="7" style="background-color:#C8E6C9;">farfetched and
# wonderful</span>, <span class="lx-highlight" data-idx="8" style="background-color:#D2E3FC;">not only impressing his audience with the appealing visuals he creates, but induces
# them to think and discuss what is going on due its scientiﬁc depth</span>. Personally, as someone who is
# bamboozled by the idea of how big the universe is, <span class="lx-highlight" data-idx="9" style="background-color:#D2E3FC;">I ﬁnd it unendingly entertaining to repeatedly
# watch this ﬁlm and understanding it more each time</span>, and can only hope the technology portrayed
# will one day come true.
# Overall, ‘Interstellar’ is <span class="lx-highlight" data-idx="10" style="background-color:#C8E6C9;">a clear example of Nolan’s auteur talent</span>, as he once again ﬁgments yet
# another cluster of conditions for us to marvel at. With a <span class="lx-highlight" data-idx="11" style="background-color:#C8E6C9;">fantastic score</span> from world famous
# composer Hanz Zimmer, his epic, orchestral theme <span class="lx-highlight" data-idx="12" style="background-color:#D2E3FC;">sets the audience in the palm of his hands as
# we stress over how we are all going to be saved once again</span>.
# &quot;&quot;&quot;
#
#
#       </div>
#       <div class="lx-controls">
#         <div class="lx-button-row">
#           <button class="lx-control-btn" onclick="playPause()">▶️ Play</button>
#           <button class="lx-control-btn" onclick="prevExtraction()">⏮ Previous</button>
#           <button class="lx-control-btn" onclick="ne

# %% [markdown]
# ---
# ##### <a id='toc1_5_7_1_2_'></a>[**>>> Bonus Exercise 3 (Take home):**](#toc0_)
#
# `NOTE: This exercise is now considered a bonus one, not counted for the main grade, only as extra points.`
#
# Repeat the steps for information extraction using a different movie reviews.
# 1. Search for movie reviews online and save them in a PDF, we suggest **at least 1 page worth of reviews** like in the example.
# 2. Load the PDF and pass them to langextract to extract information from it.
# 3. Display html with the grounded extracted attributes.
# 4. Discuss about the quality of the extracted information with langextract, how could it be improved based on the options the documentation gives that we didn't try?
#
# **`Github repository for reference:`** [langextract](https://github.com/google/langextract)

# %%
import pymupdf

pdf_path = "./data/documents/movie_review_aladdin.pdf"
formatted_text = ""
try:
    doc = pymupdf.open(pdf_path)
    for i, page in enumerate(doc):
        text = page.get_text("text")
        formatted_text += f'**Page {i + 1}**\n"""\n{text.strip()}\n"""\n\n'
    doc.close()
    print(f"✓ Extracted text from '{pdf_path}'")
except Exception as e:
    print(f"Could not read PDF: {e}")
    formatted_text = "Error: Could not process PDF file."

print(formatted_text)
# Out:
# ✓ Extracted text from './data/documents/movie_review_aladdin.pdf'
# **Page 1**
# """
# Movie Review - Aladdin
# A Familiar World
# The story of Aladdin does not change from the original. Boy meets girl, then we have our
# main characters motivation for the rest of the plot: get the girl. The girl, in this case, is a
# princess, which of course is a problem, since our main character Aladdin is a “street rat”.
# The plot does not deviate from the original at all. Aladdin finds Genie and he gets the girl,
# after a series of lies and songs. I was disappointed how closely it stuck to the original. I was
# hoping it would be more of a retelling than a remake, but either way, it was great to see a
# childhood favorite cartoon brought to life.
# The Characters
# Following the first trailers, I lost all excitement in this movie. I felt they got all the
# characters wrong and I couldn't get behind it. I tried my best to go into this movie with an
# open mind and what happened surprised me. Most of the characters grew on me very
# quickly.
# Aladdin — played by Mena Massoud — was by far my favorite character. He brought the
# same charisma that the original cartoon brought. Whenever he was on screen the movie
# was at its best. It didn't matter if he was singing, dancing, or just flashing his goofy smile,
# the movie shined when he was there.
# Jasmine was a character that, by the end of the movie, I came around on. Naomi Scott was
# great in the role; my problems were not with how she played the role, but rather how they
# made her look. When I looked at her, I really didn't see Jasmine. Her performance was so
# believable that by the end, I did see Jasmine in her.
# Jasmine had one of the bigger changes from cartoon to live action. They made her have
# more of a voice, which is another way of saying they gave her more singing to do. The
# added songs were a welcomed change.
# The Genie was one of my least liked characters. Will Smith did one thing I was very happy
# about: he did not try to be Robin Williams. With that said, he also didn't do anything great
# with the character. It seemed like he basically just tried to play himself. If you’re a fan of
# Will Smith, you will most likely enjoy the Genie, but it would have been nice to see Smith
# really try to make the part something special. His delivery on his jokes, and even the way
# he sings some of the most famous songs, you can't help but hear “The Fresh Prince” in his
# voice, which for me was distracting.
# Jafar was the weakest character in the film; Marwan Kenzari was not believable as Jafar at
# all. Some of this was his doing, but the rest was the script. Jafar wasn't really given too
# much on screen to show what his motives really are. He wants power, and will do anything
# to get it, but that's all you get from him. Kenzari, for the most part, came off as just your
# average guy. He was really lacking the evil, menacing vibe of the original Jafar. At the end,
# when Jafar goes full evil with the power of his wishes, that's when we finally see what
# Kenzari could have been doing with this character for the whole movie.
# The Songs
# The songs in the film are mostly incredible. It opens up with Smith’s rendition of “Arabian
# Nights” which was nicely done and gets you ready for the movie. “One Jump Ahead” is a
# mix of singing and action, which translates pretty well from cartoon to live action.
# When we first meet the genie we are treated to “Friend Like Me”. In the cartoon, this was
# my favorite song but in this remake, it was my least favorite.
# """
#
# **Page 2**
# """
# The visuals here are fantastic but the song just doesn't do it for me. The entire song is
# changed to fit Smith’s Genie. The way he is singing in this song, I just keep expecting the
# next words to be “In West Philadelphia……” They really leaned on Smith’s rap career for
# this song and I think its a shame, since we know Smith can do more than rap.
# The next song was my favorite: “Prince Ali”. This is where we see everything Smith can do.
# It's a great rendition of the song and a great performance. Giant groups of people singing
# and dancing in the street presenting Aladdin as a prince. It was well choreographed and
# even added some humor to the classic scene.
# The last two songs to talk about let Naomi Scott shine. Her solo song “Speechless” shows
# us that Jasmine will not be told what to do. It was a way to modernize the character, and
# eliminate the damsel in distress aspect, but it doesn't beat you over the head with it. It's a
# nice balance. Then “A Whole New World” is done perfectly. Massoud and Scott take this
# song, make it theirs, and they own it. The visuals riding around on the carpet are nothing
# short of spectacular. Disney magic is real and this scene proves it.
# “Things aren't always what they seem”
# I was expecting this movie to have some laughs but not as many as we were treated too.
# The banter between Smith and Massoud is comedy gold, which really shines when Aladdin
# meets the Sultan and Jasmine as Prince Ali for the first time. Aladdin is making a fool of
# himself and stumbling over his words with constant commentary from Genie. The scene
# ends with Genie telling Aladdin “In 10,000 years I have never been so embarrassed.” Every
# line leading up to that quote had me laughing and this was a scene begging to be
# rewatched.
# I wish to set you free
# The conclusion of this movie plays out the same as the original, which is to be expected.
# This time, Jafar never actually wishes to become a genie, but still becomes one. He is
# tricked by Aladdin just like in the original, but his wish is just to be the most powerful
# being, after which Genie tells us “there is a lot of gray area in that wish,” and then makes
# him a genie and saves the day.
# “Genie Magic”
# This movie is worth your time for the singing and dancing alone. Like I stated earlier, most
# of the songs are great, but even when the songs are not at their best, the visuals are so great
# that you forget the song is not perfect. In a time of remakes, this is a remake that I would
# recommend. Fans of the original, and newcomers, will have plenty of areas in this film to
# find joy.
# """

# %%
import langextract as lx
import textwrap

# Defining the extraction prompt for "movie review" type of data
prompt = textwrap.dedent("""\
    Extract specific opinions and their impact on the audience from this movie review.
    Important: Use exact text verbatim from the input for extraction_text. Do not paraphrase.
    Extract entities in order of appearance with no overlapping text spans.

    Use the 'opinion_statement' class for direct judgments about film elements (like plot, score, or acting).
    - 'subject' should be the element being reviewed.
    - 'sentiment' should be Positive, Negative, or Neutral.
    - 'key_phrase' should be the core descriptive words.

    Use the 'audience_impact' class for phrases describing the effect on the viewer.
    - 'emotion_evoked' should be the feeling or reaction (e.g., stress, joy, confusion).
    - 'causal_element' is what part of the film caused the reaction.
    - 'target_audience' is who was affected (e.g., 'the audience', 'the reviewer').
    """)

# Providing high-quality examples to guide the model
# These examples show the model exactly how to differentiate between the two classes
examples = [
    # Example 1: Demonstrates a positive opinion on the plot and its direct impact on the reviewer
    lx.data.ExampleData(
        text="The film boasts a truly clever plot that kept me guessing until the very end.",
        extractions=[
            lx.data.Extraction(
                extraction_class="opinion_statement",
                extraction_text="a truly clever plot",
                attributes={
                    "subject": "The plot",
                    "sentiment": "Positive",
                    "key_phrase": "truly clever"
                }
            ),
            lx.data.Extraction(
                extraction_class="audience_impact",
                extraction_text="kept me guessing until the very end",
                attributes={
                    "emotion_evoked": ["engaged", "curious"],
                    "causal_element": "The plot",
                    "target_audience": "the reviewer"
                }
            ),
        ]
    ),
    # Example 2: Shows a negative opinion and a separate audience impact caused by the soundtrack
    lx.data.ExampleData(
        text="Unfortunately, the dialogue felt clunky and unnatural, and the jarring soundtrack made the audience jump.",
        extractions=[
            lx.data.Extraction(
                extraction_class="opinion_statement",
                extraction_text="the dialogue felt clunky and unnatural",
                attributes={
                    "subject": "The dialogue",
                    "sentiment": "Negative",
                    "key_phrase": "clunky and unnatural"
                }
            ),
            lx.data.Extraction(
                extraction_class="audience_impact",
                extraction_text="made the audience jump",
                attributes={
                    "emotion_evoked": ["startled", "on edge"],
                    "causal_element": "The soundtrack",
                    "target_audience": "the audience"
                }
            )
        ]
    )
]

# %%
import os
import langextract as lx

# We define our main langextract function 
def grounded_info_extraction(input_documents, prompt, examples, file_name, model_id ="gemini-2.5-flash-lite", extraction_passes = 1, max_workers = 5, max_char_buffer = 2000):
    result = lx.extract(
        text_or_documents=input_documents,
        prompt_description=prompt,
        examples=examples,
        model_id=model_id,
        extraction_passes=extraction_passes,    # Improves recall through multiple passes over the same text, needs temperature above 0.0
        max_workers=max_workers,         # Parallel processing for speed, remember there are API call rate limits, so do not abuse
        max_char_buffer=max_char_buffer    # Smaller contexts for better accuracy, currently: 1000 characters per batch
    )

    # Display results
    print(f"Extracted {len(result.extractions)} entities:\n")
    for extraction in result.extractions:
        print(f"• {extraction.extraction_class}: '{extraction.extraction_text}'")
        if extraction.attributes:
            for key, value in extraction.attributes.items():
                print(f"  - {key}: {value}")
    
    output_dir = "./results/info_extractions"
    os.makedirs(output_dir, exist_ok=True)
    # Save results to JSONL
    lx.io.save_annotated_documents([result], output_name=f"{file_name}.jsonl", output_dir=output_dir)

    # Generate interactive visualization
    html_content2 = lx.visualize(f"{output_dir}/{file_name}.jsonl")
    with open(f"{output_dir}/{file_name}_vis.html", "w") as f:
        if hasattr(html_content2, 'data'):
            f.write(html_content2.data)
        else:
            f.write(html_content2)

    print(f"✓ Visualization saved to {output_dir}/{file_name}_vis.html")
    
    # returning html content for display
    return html_content2

html_content2 = grounded_info_extraction(formatted_text, prompt, examples, "movie_review_aladdin")
# Out:
# WARNING:google_genai._api_client:Both GOOGLE_API_KEY and GEMINI_API_KEY are set. Using GOOGLE_API_KEY.
# Extracted 61 entities:
#
# • opinion_statement: 'I was disappointed how closely it stuck to the original'
#   - subject: The plot
#   - sentiment: Negative
#   - key_phrase: disappointed how closely it stuck to the original
# • opinion_statement: 'it was great to see a childhood favorite cartoon brought to life'
#   - subject: The movie
#   - sentiment: Positive
#   - key_phrase: great to see a childhood favorite cartoon brought to life
# • opinion_statement: 'I lost all excitement in this movie'
#   - subject: The movie
#   - sentiment: Negative
#   - key_phrase: lost all excitement
# • opinion_statement: 'I felt they got all the characters wrong'
#   - subject: The characters
#   - sentiment: Negative
#   - key_phrase: got all the characters wrong
# • opinion_statement: 'Most of the characters grew on me very quickly'
#   - subject: The characters
#   - sentiment: Positive
#   - key_phrase: grew on me very quickly
# • opinion_statement: 'Aladdin — played by Mena Massoud — was by far my favorite character'
#   - subject: Aladdin
#   - sentiment: Positive
#   - key_phrase: my favorite character
# • opinion_statement: 'He brought the same charisma that the original cartoon brought'
#   - subject: Aladdin
#   - sentiment: Positive
#   - key_phrase: brought the same charisma
# • opinion_statement: 'Whenever he was on screen the movie was at its best'
#   - subject: Aladdin
#   - sentiment: Positive
#   - key_phrase: at its best
# • opinion_statement: 'the movie shined when he was there'
#   - subject: The movie
#   - sentiment: Positive
#   - key_phrase: shined
# • opinion_statement: 'Naomi Scott was great in the role'
#   - subject: Naomi Scott
#   - sentiment: Positive
#   - key_phrase: great in the role
# • opinion_statement: 'I really didn't see Jasmine'
#   - subject: Jasmine
#   - sentiment: Negative
#   - key_phrase: didn't see Jasmine
# • opinion_statement: 'Her performance was so believable that by the end, I did see Jasmine in her'
#   - subject: Her performance
#   - sentiment: Positive
#   - key_phrase: so believable
# • opinion_statement: 'The added songs were a welcomed change'
#   - subject: The added songs
#   - sentiment: Positive
#   - key_phrase: welcomed change
# • opinion_statement: 'The Genie was one of my least liked characters'
#   - subject: The Genie
#   - sentiment: Negative
#   - key_phrase: one of my least liked characters
# • opinion_statement: 'he did not try to be Robin Williams'
#   - subject: Will Smith
#   - sentiment: Positive
#   - key_phrase: did not try to be Robin Williams
# • opinion_statement: 'he also didn't do anything great with the character'
#   - subject: Will Smith's character
#   - sentiment: Negative
#   - key_phrase: didn't do anything great
# • opinion_statement: 'it would have been nice to see Smith really try to make the part something special'
#   - subject: Will Smith's performance
#   - sentiment: Negative
#   - key_phrase: nice to see Smith really try to make the part something special
# • opinion_statement: 'His delivery on his jokes, and even the way he sings some of the most famous songs, you can't help but hear “The Fresh Prince” in his voice'
#   - subject: Will Smith's delivery
#   - sentiment: Negative
#   - key_phrase: hear “The Fresh Prince” in his voice
# • audience_impact: 'was distracting'
#   - emotion_evoked: ['distracted']
#   - causal_element: Hearing "The Fresh Prince" in his voice
#   - target_audience: the reviewer
# • opinion_statement: 'Jafar was the weakest character in the film'
#   - subject: Jafar
#   - sentiment: Negative
#   - key_phrase: weakest character
# • opinion_statement: 'Marwan Kenzari was not believable as Jafar at all'
#   - subject: Marwan Kenzari's portrayal of Jafar
#   - sentiment: Negative
#   - key_phrase: not believable
# • opinion_statement: 'the rest was the script'
#   - subject: Marwan Kenzari's performance
#   - sentiment: Negative
#   - key_phrase: the script
# • opinion_statement: 'Jafar wasn't really given too much on screen to show what his motives really are'
#   - subject: Jafar's character development
#   - sentiment: Negative
#   - key_phrase: wasn't really given too much on screen
# • opinion_statement: 'Kenzari, for the most part, came off as just your average guy'
#   - subject: Marwan Kenzari's portrayal of Jafar
#   - sentiment: Negative
#   - key_phrase: came off as just your average guy
# • opinion_statement: 'He was really lacking the evil, menacing vibe of the original Jafar'
#   - subject: Marwan Kenzari's portrayal of Jafar
#   - sentiment: Negative
#   - key_phrase: lacking the evil, menacing vibe
# • opinion_statement: 'that's when we finally see what Kenzari could have been doing with this character for the whole movie'
#   - subject: Marwan Kenzari's potential
#   - sentiment: Negative
#   - key_phrase: could have been doing
# • opinion_statement: 'The songs in the film are mostly incredible'
#   - subject: The songs
#   - sentiment: Positive
#   - key_phrase: mostly incredible
# • opinion_statement: 'Smith’s rendition of “Arabian Nights” which was nicely done'
#   - subject: Smith's rendition of “Arabian Nights”
#   - sentiment: Positive
#   - key_phrase: nicely done
# • opinion_statement: '“One Jump Ahead” is a mix of singing and action, which translates pretty well from cartoon to live action'
#   - subject: “One Jump Ahead”
#   - sentiment: Positive
#   - key_phrase: translates pretty well
# • opinion_statement: 'In the cartoon, this was my favorite song but in this remake, it was my least favorite'
#   - subject: “Friend Like Me”
#   - sentiment: Negative
#   - key_phrase: my least favorite
# • opinion_statement: 'the song just doesn't do it for me'
#   - subject: The song “Friend Like Me”
#   - sentiment: Negative
#   - key_phrase: just doesn't do it for me
# • opinion_statement: 'The entire song is changed to fit Smith’s Genie'
#   - subject: The song “Friend Like Me”
#   - sentiment: Neutral
#   - key_phrase: changed to fit Smith’s Genie
# • opinion_statement: 'They really leaned on Smith’s rap career for this song and I think its a shame'
#   - subject: The song “Friend Like Me”
#   - sentiment: Negative
#   - key_phrase: its a shame
# • opinion_statement: 'since we know Smith can do more than rap'
#   - subject: Will Smith's capabilities
#   - sentiment: Positive
#   - key_phrase: can do more than rap
# • opinion_statement: 'The next song was my favorite: “Prince Ali”'
#   - subject: “Prince Ali”
#   - sentiment: Positive
#   - key_phrase: my favorite
# • opinion_statement: 'This is where we see everything Smith can do'
#   - subject: Will Smith's performance in “Prince Ali”
#   - sentiment: Positive
#   - key_phrase: everything Smith can do
# • opinion_statement: 'a great rendition of the song'
#   - subject: The song
#   - sentiment: Positive
#   - key_phrase: great rendition
# • opinion_statement: 'a great performance'
#   - subject: The performance
#   - sentiment: Positive
#   - key_phrase: great
# • opinion_statement: 'well choreographed'
#   - subject: The choreography
#   - sentiment: Positive
#   - key_phrase: well choreographed
# • opinion_statement: 'added some humor'
#   - subject: The scene
#   - sentiment: Positive
#   - key_phrase: added some humor
# • opinion_statement: 'Her solo song “Speechless” shows us that Jasmine will not be told what to do.'
#   - subject: Jasmine's character
#   - sentiment: Positive
#   - key_phrase: will not be told what to do
# • opinion_statement: 'It was a way to modernize the character'
#   - subject: The song
#   - sentiment: Positive
#   - key_phrase: modernize the character
# • opinion_statement: 'eliminate the damsel in distress aspect'
#   - subject: The character
#   - sentiment: Positive
#   - key_phrase: eliminate the damsel in distress aspect
# • opinion_statement: 'it doesn't beat you over the head with it.'
#   - subject: The modernization
#   - sentiment: Positive
#   - key_phrase: doesn't beat you over the head
# • opinion_statement: 'It's a nice balance.'
#   - subject: The modernization
#   - sentiment: Positive
#   - key_phrase: nice balance
# • opinion_statement: 'Then “A Whole New World” is done perfectly.'
#   - subject: The song 'A Whole New World'
#   - sentiment: Positive
#   - key_phrase: done perfectly
# • opinion_statement: 'Massoud and Scott take this song, make it theirs, and they own it.'
#   - subject: Massoud and Scott's performance
#   - sentiment: Positive
#   - key_phrase: make it theirs, and they own it
# • opinion_statement: 'The visuals riding around on the carpet are nothing short of spectacular.'
#   - subject: The visuals
#   - sentiment: Positive
#   - key_phrase: nothing short of spectacular
# • opinion_statement: 'Disney magic is real and this scene proves it.'
#   - subject: Disney magic
#   - sentiment: Positive
#   - key_phrase: is real and this scene proves it
# • opinion_statement: 'I was expecting this movie to have some laughs but not as many as we were treated too.'
#   - subject: The movie's humor
#   - sentiment: Positive
#   - key_phrase: not as many as we were treated too
# • opinion_statement: 'The banter between Smith and Massoud is comedy gold'
#   - subject: The banter
#   - sentiment: Positive
#   - key_phrase: comedy gold
# • opinion_statement: 'Every line leading up to that quote had me laughing'
#   - subject: The lines
#   - sentiment: Positive
#   - key_phrase: had me laughing
# • audience_impact: 'had me laughing'
#   - emotion_evoked: ['laughter']
#   - causal_element: Every line leading up to that quote
#   - target_audience: the reviewer
# • opinion_statement: 'this was a scene begging to be rewatched.'
#   - subject: The scene
#   - sentiment: Positive
#   - key_phrase: begging to be rewatched
# • opinion_statement: 'This time, Jafar never actually wishes to become a genie, but still becomes one.'
#   - subject: Jafar's character arc
#   - sentiment: Neutral
#   - key_phrase: never actually wishes to become a genie, but still becomes one
# • opinion_statement: 'there is a lot of gray area in that wish'
#   - subject: Jafar's wish
#   - sentiment: Neutral
#   - key_phrase: a lot of gray area
# • opinion_statement: 'This movie is worth your time for the singing and dancing alone.'
#   - subject: The movie
#   - sentiment: Positive
#   - key_phrase: worth your time for the singing and dancing alone
# • opinion_statement: 'most of the songs are great'
#   - subject: The songs
#   - sentiment: Positive
#   - key_phrase: great
# • opinion_statement: 'even when the songs are not at their best, the visuals are so great that you forget the song is not perfect.'
#   - subject: The visuals
#   - sentiment: Positive
#   - key_phrase: so great that you forget the song is not perfect
# • opinion_statement: 'this is a remake that I would recommend'
#   - subject: This remake
#   - sentiment: Positive
#   - key_phrase: would recommend
# • audience_impact: 'Fans of the original, and newcomers, will have plenty of areas in this film to find joy'
#   - emotion_evoked: ['joy']
#   - causal_element: plenty of areas in this film
#   - target_audience: Fans of the original, and newcomers
# LangExtract: Saving to movie_review_aladdin.jsonl: 1 docs [00:00, 574.40 docs/s]
# ✓ Saved 1 documents to movie_review_aladdin.jsonl
# LangExtract: Loading movie_review_aladdin.jsonl: 100%|██████████| 30.0k/30.0k [00:00<00:00, 54.2MB/s]
# ✓ Loaded 1 documents from movie_review_aladdin.jsonl
# ✓ Visualization saved to ./results/info_extractions/movie_review_aladdin_vis.html

# %%
import json
# We can also observe the structure of the raw extracted data
with open("./results/info_extractions/movie_review_aladdin.jsonl", "r") as f:
    content_extracted_raw = json.load(f)
content_extracted_raw
# Out:
# {'extractions': [{'extraction_class': 'opinion_statement',
#    'extraction_text': 'I was disappointed how closely it stuck to the original',
#    'char_interval': {'start_pos': 466, 'end_pos': 521},
#    'alignment_status': 'match_exact',
#    'extraction_index': 1,
#    'group_index': 0,
#    'description': None,
#    'attributes': {'subject': 'The plot',
#     'sentiment': 'Negative',
#     'key_phrase': 'disappointed how closely it stuck to the original'}},
#   {'extraction_class': 'opinion_statement',
#    'extraction_text': 'it was great to see a childhood favorite cartoon brought to life',
#    'char_interval': {'start_pos': 600, 'end_pos': 665},
#    'alignment_status': 'match_exact',
#    'extraction_index': 2,
#    'group_index': 1,
#    'description': None,
#    'attributes': {'subject': 'The movie',
#     'sentiment': 'Positive',
#     'key_phrase': 'great to see a childhood favorite cartoon brought to life'}},
#   {'extraction_class': 'opinion_statement',
#    'extraction_text': 'I lost all excitement in this movie',
#    'char_interval': {'start_pos': 714, 'end_pos': 749},
#    'alignment_status': 'match_exact',
#    'extraction_index': 3,
#    'group_index': 2,
#    'description': None,
#    'attributes': {'subject': 'The movie',
#     'sentiment': 'Negative',
#     'key_phrase': 'lost all excitement'}},
#   {'extraction_class': 'opinion_statement',
#    'extraction_text': 'I felt they got all the characters wrong',
#    'char_interval': {'start_pos': 751, 'end_pos': 792},
#    'alignment_status': 'match_exact',
#    'extraction_index': 4,
#    'group_index': 3,
#    'description': None,
#    'attributes': {'subject': 'The characters',
#     'sentiment': 'Negative',
#     'key_phrase': 'got all the characters wrong'}},
#   {'extraction_class': 'opinion_statement',
#    'extraction_text': 'Most of the characters grew on me very quickly',
#    'char_interval': {'start_pos': 912, 'end_pos': 959},
#    'alignment_status': 'match_exact',
#    'extraction_index': 5,
#    'group_index': 4,
#    'description': None,
#    'attributes': {'subject': 'The characters',
#     'sentiment': 'Positive',
#     'key_phrase': 'grew on me very quickly'}},
#   {'extraction_class': 'opinion_statement',
#    'extraction_text': 'Aladdin — played by Mena Massoud — was by far my favorite character',
#    'char_interval': {'start_pos': 962, 'end_pos': 1029},
#    'alignment_status': 'match_exact',
#    'extraction_index': 6,
#    'group_index': 5,
#    'description': None,
#    'attributes': {'subject': 'Aladdin',
#     'sentiment': 'Positive',
#     'key_phrase': 'my favorite character'}},
#   {'extraction_class': 'opinion_statement',
#    'extraction_text': 'He brought the same charisma that the original cartoon brought',
#    'char_interval': {'start_pos': 1031, 'end_pos': 1094},
#    'alignment_status': 'match_exact',
#    'extraction_index': 7,
#    'group_index': 6,
#    'description': None,
#    'attributes': {'subject': 'Aladdin',
#     'sentiment': 'Positive',
#     'key_phrase': 'brought the same charisma'}},
#   {'extraction_class': 'opinion_statement',
#    'extraction_text': 'Whenever he was on screen the movie was at its best',
#    'char_interval': {'start_pos': 1096, 'end_pos': 1148},
#    'alignment_status': 'match_exact',
#    'extraction_index': 8,
#    'group_index': 7,
#    'description': None,
#    'attributes': {'subject': 'Aladdin',
#     'sentiment': 'Positive',
#     'key_phrase': 'at its best'}},
#   {'extraction_class': 'opinion_statement',
#    'extraction_text': 'the movie shined when he was there',
#    'char_interval': {'start_pos': 1230, 'end_pos': 1264},
#    'alignment_status': 'match_exact',
#    'extraction_index': 9,
#    'group_index': 8,
#    'description': None,
#    'attributes': {'subject': 'The movie',
#     'sentiment': 'Positive',
#     'key_phrase': 'shined'}},
#   {'extraction_class': 'opinion_statement',
#    'extraction_text': 'Naomi Scott was great in the role',
#    'char_interval': {'start_pos': 1340, 'end_pos': 1374},
#    'alignment_status': 'match_exact',
#    'extraction_index': 10,
#    'group_index': 9,
#    'description': None,
#    'attributes': {'subject': 'Naomi Scott',
#     'sentiment': 'Positive',
#     'key_phrase': 'great in the role'}},
#   {'extraction_class': 'opinion_statement',
#    'extraction_text': "I really didn't see Jasmine",
#    'char_interval': {'start_pos': 1485, 'end_pos': 1512},
#    'alignment_status': 'match_exact',
#    'extraction_index': 11,
#    'group_index': 10,
#    'description': None,
#    'attributes': {'subject': 'Jasmine',
#     'sentiment': 'Negative',
#     'key_phrase': "didn't see Jasmine"}},
#   {'extraction_class': 'opinion_statement',
#    'extraction_text': 'Her performance was so believable that by the end, I did see Jasmine in her',
#    'char_interval': {'start_pos': 1514, 'end_pos': 1590},
#    'alignment_status': 'match_exact',
#    'extraction_index': 12,
#    'group_index': 11,
#    'description': None,
#    'attributes': {'subject': 'Her performance',
#     'sentiment': 'Positive',
#     'key_phrase': 'so believable'}},
#   {'extraction_class': 'opinion_statement',
#    'extraction_text': 'The added songs were a welcomed change',
#    'char_interval': {'start_pos': 1762, 'end_pos': 1801},
#    'alignment_status': 'match_exact',
#    'extraction_index': 13,
#    'group_index': 12,
#    'description': None,
#    'attributes': {'subject': 'The added songs',
#     'sentiment': 'Positive',
#     'key_phrase': 'welcomed change'}},
#   {'extraction_class': 'opinion_statement',
#    'extraction_text': 'The Genie was one of my least liked characters',
#    'char_interval': {'start_pos': 1804, 'end_pos': 1850},
#    'alignment_status': 'match_exact',
#    'extraction_index': 14,
#    'group_index': 13,
#    'description': None,
#    'attributes': {'subject': 'The Genie',
#     'sentiment': 'Negative',
#     'key_phrase': 'one of my least liked characters'}},
#   {'extraction_class': 'opinion_statement',
#    'extraction_text': 'he did not try to be Robin Williams',
#    'char_interval': {'start_pos': 1902, 'end_pos': 1937},
#    'alignment_status': 'match_exact',
#    'extraction_index': 15,
#    'group_index': 14,
#    'description': None,
#    'attributes': {'subject': 'Will Smith',
#     'sentiment': 'Positive',
#     'key_phrase': 'did not try to be Robin Williams'}},
#   {'extraction_class': 'opinion_statement',
#    'extraction_text': "he also didn't do anything great with the character",
#    'char_interval': {'start_pos': 1955, 'end_pos': 2007},
#    'alignment_status': 'match_exact',
#    'extraction_index': 1,
#    'group_index': 0,
#    'description': None,
#    'attributes': {'subject': "Will Smith's character",
#     'sentiment': 'Negative',
#     'key_phrase': "didn't do anything great"}},
#   {'extraction_class': 'opinion_statement',
#    'extraction_text': 'it would have been nice to see Smith really try to make the part something special',
#    'char_interval': {'start_pos': 2139, 'end_pos': 2222},
#    'alignment_status': 'match_exact',
#    'extraction_index': 2,
#    'group_index': 1,
#    'description': None,
#    'attributes': {'subject': "Will Smith's performance",
#     'sentiment': 'Negative',
#     'key_phrase': 'nice to see Smith really try to make the part something special'}},
#   {'extraction_class': 'opinion_statement',
#    'extraction_text': "His delivery on his jokes, and even the way he sings some of the most famous songs, you can't help but hear “The Fresh Prince” in his voice",
#    'char_interval': {'start_pos': 2224, 'end_pos': 2365},
#    'alignment_status': 'match_exact',
#    'extraction_index': 3,
#    'group_index': 2,
#    'description': None,
#    'attributes': {'subject': "Will Smith's delivery",
#     'sentiment': 'Negative',
#     'key_phrase': 'hear “The Fresh Prince” in his voice'}},
#   {'extraction_class': 'audience_impact',
#    'extraction_text': 'was distracting',
#    'char_interval': {'start_pos': 2380, 'end_pos': 2395},
#    'alignment_status': 'match_exact',
#    'extraction_index': 4,
#    'group_index': 3,
#    'description': None,
#    'attributes': {'emotion_evoked': ['distracted'],
#     'causal_element': 'Hearing "The Fresh Prince" in his voice',
#     'target_audience': 'the reviewer'}},
#   {'extraction_class': 'opinion_statement',
#    'extraction_text': 'Jafar was the weakest character in the film',
#    'char_interval': {'start_pos': 2398, 'end_pos': 2441},
#    'alignment_status': 'match_exact',
#    'extraction_index': 5,
#    'group_index': 4,
#    'description': None,
#    'attributes': {'subject': 'Jafar',
#     'sentiment': 'Negative',
#     'key_phrase': 'weakest character'}},
#   {'extraction_class': 'opinion_statement',
#    'extraction_text': 'Marwan Kenzari was not believable as Jafar at all',
#    'char_interval': {'start_pos': 2443, 'end_pos': 2493},
#    'alignment_status': 'match_exact',
#    'extraction_index': 6,
#    'group_index': 5,
#    'description': None,
#    'attributes': {'subject': "Marwan Kenzari's portrayal of Jafar",
#     'sentiment': 'Negative',
#     'key_phrase': 'not believable'}},
#   {'extraction_class': 'opinion_statement',
#    'extraction_text': 'the rest was the script',
#    'char_interval': {'start_pos': 2527, 'end_pos': 2550},
#    'alignment_status': 'match_exact',
#    'extraction_index': 7,
#    'group_index': 6,
#    'description': None,
#    'attributes': {'subject': "Marwan Kenzari's performance",
#     'sentiment': 'Negative',
#     'key_phrase': 'the script'}},
#   {'extraction_class': 'opinion_statement',
#    'extraction_text': "Jafar wasn't really given too much on screen to show what his motives really are",
#    'char_interval': {'start_pos': 2552, 'end_pos': 2633},
#    'alignment_status': 'match_exact',
#    'extraction_index': 8,
#    'group_index': 7,
#    'description': None,
#    'attributes': {'subject': "Jafar's character development",
#     'sentiment': 'Negative',
#     'key_phrase': "wasn't really given too much on screen"}},
#   {'extraction_class': 'opinion_statement',
#    'extraction_text': 'Kenzari, for the most part, came off as just your average guy',
#    'char_interval': {'start_pos': 2717, 'end_pos': 2779},
#    'alignment_status': 'match_exact',
#    'extraction_index': 9,
#    'group_index': 8,
#    'description': None,
#    'attributes': {'subject': "Marwan Kenzari's portrayal of Jafar",
#     'sentiment': 'Negative',
#     'key_phrase': 'came off as just your average guy'}},
#   {'extraction_class': 'opinion_statement',
#    'extraction_text': 'He was really lacking the evil, menacing vibe of the original Jafar',
#    'char_interval': {'start_pos': 2781, 'end_pos': 2848},
#    'alignment_status': 'match_exact',
#    'extraction_index': 10,
#    'group_index': 9,
#    'description': None,
#    'attributes': {'subject': "Marwan Kenzari's portrayal of Jafar",
#     'sentiment': 'Negative',
#     'key_phrase': 'lacking the evil, menacing vibe'}},
#   {'extraction_class': 'opinion_statement',
#    'extraction_text': "that's when we finally see what Kenzari could have been doing with this character for the whole movie",
#    'char_interval': {'start_pos': 2919, 'end_pos': 3021},
#    'alignment_status': 'match_exact',
#    'extraction_index': 11,
#    'group_index': 10,
#    'description': None,
#    'attributes': {'subject': "Marwan Kenzari's potential",
#     'sentiment': 'Negative',
#     'key_phrase': 'could have been doing'}},
#   {'extraction_class': 'opinion_statement',
#    'extraction_text': 'The songs in the film are mostly incredible',
#    'char_interval': {'start_pos': 3035, 'end_pos': 3078},
#    'alignment_status': 'match_exact',
#    'extraction_index': 12,
#    'group_index': 11,
#    'description': None,
#    'attributes': {'subject': 'The songs',
#     'sentiment': 'Positive',
#     'key_phrase': 'mostly incredible'}},
#   {'extraction_class': 'opinion_statement',
#    'extraction_text': 'Smith’s rendition of “Arabian Nights” which was nicely done',
#    'char_interval': {'start_pos': 3097, 'end_pos': 3157},
#    'alignment_status': 'match_exact',
#    'extraction_index': 13,
#    'group_index': 12,
#    'description': None,
#    'attributes': {'subject': "Smith's rendition of “Arabian Nights”",
#     'sentiment': 'Positive',
#     'key_phrase': 'nicely done'}},
#   {'extraction_class': 'opinion_statement',
#    'extraction_text': '“One Jump Ahead” is a mix of singing and action, which translates pretty well from cartoon to live action',
#    'char_interval': {'start_pos': 3192, 'end_pos': 3298},
#    'alignment_status': 'match_exact',
#    'extraction_index': 14,
#    'group_index': 13,
#    'description': None,
#    'attributes': {'subject': '“One Jump Ahead”',
#     'sentiment': 'Positive',
#     'key_phrase': 'translates pretty well'}},
#   {'extraction_class': 'opinion_statement',
#    'extraction_text': 'In the cartoon, this was my favorite song but in this remake, it was my least favorite',
#    'char_interval': {'start_pos': 3366, 'end_pos': 3453},
#    'alignment_status': 'match_exact',
#    'extraction_index': 15,
#    'group_index': 14,
#    'description': None,
#    'attributes': {'subject': '“Friend Like Me”',
#     'sentiment': 'Negative',
#     'key_phrase': 'my least favorite'}},
#   {'extraction_class': 'opinion_statement',
#    'extraction_text': "the song just doesn't do it for me",
#    'char_interval': {'start_pos': 3510, 'end_pos': 3544},
#    'alignment_status': 'match_exact',
#    'extraction_index': 16,
#    'group_index': 15,
#    'description': None,
#    'attributes': {'subject': 'The song “Friend Like Me”',
#     'sentiment': 'Negative',
#     'key_phrase': "just doesn't do it for me"}},
#   {'extraction_class': 'opinion_statement',
#    'extraction_text': 'The entire song is changed to fit Smith’s Genie',
#    'char_interval': {'start_pos': 3546, 'end_pos': 3594},
#    'alignment_status': 'match_exact',
#    'extraction_index': 17,
#    'group_index': 16,
#    'description': None,
#    'attributes': {'subject': 'The song “Friend Like Me”',
#     'sentiment': 'Neutral',
#     'key_phrase': 'changed to fit Smith’s Genie'}},
#   {'extraction_class': 'opinion_statement',
#    'extraction_text': 'They really leaned on Smith’s rap career for this song and I think its a shame',
#    'char_interval': {'start_pos': 3701, 'end_pos': 3780},
#    'alignment_status': 'match_exact',
#    'extraction_index': 18,
#    'group_index': 17,
#    'description': None,
#    'attributes': {'subject': 'The song “Friend Like Me”',
#     'sentiment': 'Negative',
#     'key_phrase': 'its a shame'}},
#   {'extraction_class': 'opinion_statement',
#    'extraction_text': 'since we know Smith can do more than rap',
#    'char_interval': {'start_pos': 3782, 'end_pos': 3822},
#    'alignment_status': 'match_exact',
#    'extraction_index': 19,
#    'group_index': 18,
#    'description': None,
#    'attributes': {'subject': "Will Smith's capabilities",
#     'sentiment': 'Positive',
#     'key_phrase': 'can do more than rap'}},
#   {'extraction_class': 'opinion_statement',
#    'extraction_text': 'The next song was my favorite: “Prince Ali”',
#    'char_interval': {'start_pos': 3825, 'end_pos': 3867},
#    'alignment_status': 'match_lesser',
#    'extraction_index': 20,
#    'group_index': 19,
#    'description': None,
#    'attributes': {'subject': '“Prince Ali”',
#     'sentiment': 'Positive',
#     'key_phrase': 'my favorite'}},
#   {'extraction_class': 'opinion_statement',
#    'extraction_text': 'This is where we see everything Smith can do',
#    'char_interval': {'start_pos': 3870, 'end_pos': 3914},
#    'alignment_status': 'match_exact',
#    'extraction_index': 21,
#    'group_index': 20,
#    'description': None,
#    'attributes': {'subject': "Will Smith's performance in “Prince Ali”",
#     'sentiment': 'Positive',
#     'key_phrase': 'everything Smith can do'}},
#   {'extraction_class': 'opinion_statement',
#    'extraction_text': 'a great rendition of the song',
#    'char_interval': {'start_pos': 3922, 'end_pos': 3951},
#    'alignment_status': 'match_exact',
#    'extraction_index': 1,
#    'group_index': 0,
#    'description': None,
#    'attributes': {'subject': 'The song',
#     'sentiment': 'Positive',
#     'key_phrase': 'great rendition'}},
#   {'extraction_class': 'opinion_statement',
#    'extraction_text': 'a great performance',
#    'char_interval': {'start_pos': 3956, 'end_pos': 3975},
#    'alignment_status': 'match_exact',
#    'extraction_index': 2,
#    'group_index': 1,
#    'description': None,
#    'attributes': {'subject': 'The performance',
#     'sentiment': 'Positive',
#     'key_phrase': 'great'}},
#   {'extraction_class': 'opinion_statement',
#    'extraction_text': 'well choreographed',
#    'char_interval': {'start_pos': 4074, 'end_pos': 4092},
#    'alignment_status': 'match_exact',
#    'extraction_index': 3,
#    'group_index': 2,
#    'description': None,
#    'attributes': {'subject': 'The choreography',
#     'sentiment': 'Positive',
#     'key_phrase': 'well choreographed'}},
#   {'extraction_class': 'opinion_statement',
#    'extraction_text': 'added some humor',
#    'char_interval': {'start_pos': 4103, 'end_pos': 4119},
#    'alignment_status': 'match_exact',
#    'extraction_index': 4,
#    'group_index': 3,
#    'description': None,
#    'attributes': {'subject': 'The scene',
#     'sentiment': 'Positive',
#     'key_phrase': 'added some humor'}},
#   {'extraction_class': 'opinion_statement',
#    'extraction_text': 'Her solo song “Speechless” shows us that Jasmine will not be told what to do.',
#    'char_interval': {'start_pos': 4199, 'end_pos': 4277},
#    'alignment_status': 'match_exact',
#    'extraction_index': 5,
#    'group_index': 4,
#    'description': None,
#    'attributes': {'subject': "Jasmine's character",
#     'sentiment': 'Positive',
#     'key_phrase': 'will not be told what to do'}},
#   {'extraction_class': 'opinion_statement',
#    'extraction_text': 'It was a way to modernize the character',
#    'char_interval': {'start_pos': 4278, 'end_pos': 4317},
#    'alignment_status': 'match_exact',
#    'extraction_index': 6,
#    'group_index': 5,
#    'description': None,
#    'attributes': {'subject': 'The song',
#     'sentiment': 'Positive',
#     'key_phrase': 'modernize the character'}},
#   {'extraction_class': 'opinion_statement',
#    'extraction_text': 'eliminate the damsel in distress aspect',
#    'char_interval': {'start_pos': 4324, 'end_pos': 4363},
#    'alignment_status': 'match_exact',
#    'extraction_index': 7,
#    'group_index': 6,
#    'description': None,
#    'attributes': {'subject': 'The character',
#     'sentiment': 'Positive',
#     'key_phrase': 'eliminate the damsel in distress aspect'}},
#   {'extraction_class': 'opinion_statement',
#    'extraction_text': "it doesn't beat you over the head with it.",
#    'char_interval': {'start_pos': 4369, 'end_pos': 4411},
#    'alignment_status': 'match_exact',
#    'extraction_index': 8,
#    'group_index': 7,
#    'description': None,
#    'attributes': {'subject': 'The modernization',
#     'sentiment': 'Positive',
#     'key_phrase': "doesn't beat you over the head"}},
#   {'extraction_class': 'opinion_statement',
#    'extraction_text': "It's a nice balance.",
#    'char_interval': {'start_pos': 4412, 'end_pos': 4433},
#    'alignment_status': 'match_exact',
#    'extraction_index': 9,
#    'group_index': 8,
#    'description': None,
#    'attributes': {'subject': 'The modernization',
#     'sentiment': 'Positive',
#     'key_phrase': 'nice balance'}},
#   {'extraction_class': 'opinion_statement',
#    'extraction_text': 'Then “A Whole New World” is done perfectly.',
#    'char_interval': {'start_pos': 4434, 'end_pos': 4477},
#    'alignment_status': 'match_exact',
#    'extraction_index': 10,
#    'group_index': 9,
#    'description': None,
#    'attributes': {'subject': "The song 'A Whole New World'",
#     'sentiment': 'Positive',
#     'key_phrase': 'done perfectly'}},
#   {'extraction_class': 'opinion_statement',
#    'extraction_text': 'Massoud and Scott take this song, make it theirs, and they own it.',
#    'char_interval': {'start_pos': 4478, 'end_pos': 4545},
#    'alignment_status': 'match_exact',
#    'extraction_index': 11,
#    'group_index': 10,
#    'description': None,
#    'attributes': {'subject': "Massoud and Scott's performance",
#     'sentiment': 'Positive',
#     'key_phrase': 'make it theirs, and they own it'}},
#   {'extraction_class': 'opinion_statement',
#    'extraction_text': 'The visuals riding around on the carpet are nothing short of spectacular.',
#    'char_interval': {'start_pos': 4546, 'end_pos': 4620},
#    'alignment_status': 'match_exact',
#    'extraction_index': 12,
#    'group_index': 11,
#    'description': None,
#    'attributes': {'subject': 'The visuals',
#     'sentiment': 'Positive',
#     'key_phrase': 'nothing short of spectacular'}},
#   {'extraction_class': 'opinion_statement',
#    'extraction_text': 'Disney magic is real and this scene proves it.',
#    'char_interval': {'start_pos': 4621, 'end_pos': 4667},
#    'alignment_status': 'match_exact',
#    'extraction_index': 13,
#    'group_index': 12,
#    'description': None,
#    'attributes': {'subject': 'Disney magic',
#     'sentiment': 'Positive',
#     'key_phrase': 'is real and this scene proves it'}},
#   {'extraction_class': 'opinion_statement',
#    'extraction_text': 'I was expecting this movie to have some laughs but not as many as we were treated too.',
#    'char_interval': {'start_pos': 4708, 'end_pos': 4794},
#    'alignment_status': 'match_exact',
#    'extraction_index': 14,
#    'group_index': 13,
#    'description': None,
#    'attributes': {'subject': "The movie's humor",
#     'sentiment': 'Positive',
#     'key_phrase': 'not as many as we were treated too'}},
#   {'extraction_class': 'opinion_statement',
#    'extraction_text': 'The banter between Smith and Massoud is comedy gold',
#    'char_interval': {'start_pos': 4796, 'end_pos': 4847},
#    'alignment_status': 'match_exact',
#    'extraction_index': 15,
#    'group_index': 14,
#    'description': None,
#    'attributes': {'subject': 'The banter',
#     'sentiment': 'Positive',
#     'key_phrase': 'comedy gold'}},
#   {'extraction_class': 'opinion_statement',
#    'extraction_text': 'Every line leading up to that quote had me laughing',
#    'char_interval': {'start_pos': 5144, 'end_pos': 5196},
#    'alignment_status': 'match_exact',
#    'extraction_index': 16,
#    'group_index': 15,
#    'description': None,
#    'attributes': {'subject': 'The lines',
#     'sentiment': 'Positive',
#     'key_phrase': 'had me laughing'}},
#   {'extraction_class': 'audience_impact',
#    'extraction_text': 'had me laughing',
#    'char_interval': {'start_pos': 5181, 'end_pos': 5196},
#    'alignment_status': 'match_fuzzy',
#    'extraction_index': 17,
#    'group_index': 16,
#    'description': None,
#    'attributes': {'emotion_evoked': ['laughter'],
#     'causal_element': 'Every line leading up to that quote',
#     'target_audience': 'the reviewer'}},
#   {'extraction_class': 'opinion_statement',
#    'extraction_text': 'this was a scene begging to be rewatched.',
#    'char_interval': {'start_pos': 5201, 'end_pos': 5243},
#    'alignment_status': 'match_exact',
#    'extraction_index': 18,
#    'group_index': 17,
#    'description': None,
#    'attributes': {'subject': 'The scene',
#     'sentiment': 'Positive',
#     'key_phrase': 'begging to be rewatched'}},
#   {'extraction_class': 'opinion_statement',
#    'extraction_text': 'This time, Jafar never actually wishes to become a genie, but still becomes one.',
#    'char_interval': {'start_pos': 5360, 'end_pos': 5440},
#    'alignment_status': 'match_exact',
#    'extraction_index': 19,
#    'group_index': 18,
#    'description': None,
#    'attributes': {'subject': "Jafar's character arc",
#     'sentiment': 'Neutral',
#     'key_phrase': 'never actually wishes to become a genie, but still becomes one'}},
#   {'extraction_class': 'opinion_statement',
#    'extraction_text': 'there is a lot of gray area in that wish',
#    'char_interval': {'start_pos': 5575, 'end_pos': 5615},
#    'alignment_status': 'match_exact',
#    'extraction_index': 20,
#    'group_index': 19,
#    'description': None,
#    'attributes': {'subject': "Jafar's wish",
#     'sentiment': 'Neutral',
#     'key_phrase': 'a lot of gray area'}},
#   {'extraction_class': 'opinion_statement',
#    'extraction_text': 'This movie is worth your time for the singing and dancing alone.',
#    'char_interval': {'start_pos': 5681, 'end_pos': 5745},
#    'alignment_status': 'match_exact',
#    'extraction_index': 21,
#    'group_index': 20,
#    'description': None,
#    'attributes': {'subject': 'The movie',
#     'sentiment': 'Positive',
#     'key_phrase': 'worth your time for the singing and dancing alone'}},
#   {'extraction_class': 'opinion_statement',
#    'extraction_text': 'most of the songs are great',
#    'char_interval': {'start_pos': 5769, 'end_pos': 5797},
#    'alignment_status': 'match_exact',
#    'extraction_index': 22,
#    'group_index': 21,
#    'description': None,
#    'attributes': {'subject': 'The songs',
#     'sentiment': 'Positive',
#     'key_phrase': 'great'}},
#   {'extraction_class': 'opinion_statement',
#    'extraction_text': 'even when the songs are not at their best, the visuals are so great that you forget the song is not perfect.',
#    'char_interval': {'start_pos': 5803, 'end_pos': 5912},
#    'alignment_status': 'match_exact',
#    'extraction_index': 23,
#    'group_index': 22,
#    'description': None,
#    'attributes': {'subject': 'The visuals',
#     'sentiment': 'Positive',
#     'key_phrase': 'so great that you forget the song is not perfect'}},
#   {'extraction_class': 'opinion_statement',
#    'extraction_text': 'this is a remake that I would recommend',
#    'char_interval': {'start_pos': 5935, 'end_pos': 5975},
#    'alignment_status': 'match_exact',
#    'extraction_index': 1,
#    'group_index': 0,
#    'description': None,
#    'attributes': {'subject': 'This remake',
#     'sentiment': 'Positive',
#     'key_phrase': 'would recommend'}},
#   {'extraction_class': 'audience_impact',
#    'extraction_text': 'Fans of the original, and newcomers, will have plenty of areas in this film to find joy',
#    'char_interval': {'start_pos': 5977, 'end_pos': 6065},
#    'alignment_status': 'match_exact',
#    'extraction_index': 2,
#    'group_index': 1,
#    'description': None,
#    'attributes': {'emotion_evoked': ['joy'],
#     'causal_element': 'plenty of areas in this film',
#     'target_audience': 'Fans of the original, and newcomers'}}],
#  'text': '**Page 1**\n"""\nMovie Review - Aladdin \nA Familiar World \nThe story of Aladdin does not change from the original. Boy meets girl, then we have our \nmain characters motivation for the rest of the plot: get the girl. The girl, in this case, is a \nprincess, which of course is a problem, since our main character Aladdin is a “street rat”. \nThe plot does not deviate from the original at all. Aladdin finds Genie and\xa0he gets the girl, \nafter a series of lies and songs. I was disappointed how closely it stuck to the original. I was \nhoping it would be more of a retelling than a remake, but either way, it was great to see a \nchildhood favorite cartoon brought to life. \nThe Characters \nFollowing the first trailers, I lost all excitement in this movie. I felt they got all the \ncharacters wrong and I couldn\'t get behind it. I tried my best to go into this movie with an \nopen mind and what happened surprised me. Most of the characters grew on me very \nquickly. \nAladdin — played by Mena Massoud — was by far my favorite character. He brought the \nsame charisma that the original cartoon brought. Whenever he was on screen the movie \nwas at its best. It didn\'t matter if he was singing, dancing, or just flashing his goofy smile, \nthe movie shined when he was there. \nJasmine was a character that, by the end of the movie, I came around on. Naomi Scott was \ngreat in the role; my problems were not with how she played the role, but rather how they \nmade her look. When I looked at her, I really didn\'t see Jasmine. Her performance was so \nbelievable that by the end, I did see Jasmine in her. \nJasmine had one of the bigger changes from cartoon to live action. They made her have \nmore of a voice, which is another way of saying they gave her more singing to do. The \nadded songs were a welcomed change. \nThe Genie was one of my least liked characters. Will Smith did one thing I was very happy \nabout: he did not try to be Robin Williams. With that said, he also didn\'t do anything great \nwith the character. It seemed like he basically just tried to play himself. If you’re a fan of \nWill Smith, you will most likely enjoy the Genie, but it would have been nice to see Smith \nreally try to make the part something special. His delivery on his jokes, and even the way \nhe sings some of the most famous songs, you can\'t help but hear “The Fresh Prince” in his \nvoice, which for me was distracting. \nJafar was the weakest character in the film; Marwan Kenzari was not believable as Jafar at \nall. Some of this was his doing, but the rest was the script. Jafar wasn\'t really given too \nmuch on screen to show what his motives really are. He wants power, and will do anything \nto get it, but that\'s all you get from him. Kenzari, for the most part, came off as just your \naverage guy. He was really lacking the evil, menacing vibe of the original Jafar. At the end, \nwhen Jafar goes full evil with the power of his wishes, that\'s when we finally see what \nKenzari could have been doing with this character for the whole movie. \nThe Songs \nThe songs in the film are mostly incredible. It opens up with Smith’s rendition of “Arabian \nNights” which was nicely done and gets you ready for the movie. “One Jump Ahead” is a \nmix of singing and action, which translates pretty well from cartoon to live action. \nWhen we first meet the genie we are treated to “Friend Like Me”. In the cartoon, this was \nmy favorite song but in this remake, it was my least favorite.\n"""\n\n**Page 2**\n"""\nThe visuals here are fantastic but the song just doesn\'t do it for me. The entire song is \nchanged to fit Smith’s Genie. The way he is singing in this song, I just keep expecting the \nnext words to be “In West Philadelphia……” They really leaned on Smith’s rap career for \nthis song and I think its a shame, since we know Smith can do more than rap. \nThe next song was my favorite: “Prince Ali”. This is where we see everything Smith can do. \nIt\'s ...
#  'document_id': 'doc_666c270e'}

# %%
html_content2
# Out:
# <style>
# .lx-highlight { position: relative; border-radius:3px; padding:1px 2px;}
# .lx-highlight .lx-tooltip {
#   visibility: hidden;
#   opacity: 0;
#   transition: opacity 0.2s ease-in-out;
#   background: #333;
#   color: #fff;
#   text-align: left;
#   border-radius: 4px;
#   padding: 6px 8px;
#   position: absolute;
#   z-index: 1000;
#   bottom: 125%;
#   left: 50%;
#   transform: translateX(-50%);
#   font-size: 12px;
#   max-width: 240px;
#   white-space: normal;
#   box-shadow: 0 2px 6px rgba(0,0,0,0.3);
# }
# .lx-highlight:hover .lx-tooltip { visibility: visible; opacity:1; }
# .lx-animated-wrapper { max-width: 100%; font-family: Arial, sans-serif; }
# .lx-controls {
#   background: #fafafa; border: 1px solid #90caf9; border-radius: 8px;
#   padding: 12px; margin-bottom: 16px;
# }
# .lx-button-row {
#   display: flex; justify-content: center; gap: 8px; margin-bottom: 12px;
# }
# .lx-control-btn {
#   background: #4285f4; color: white; border: none; border-radius: 4px;
#   padding: 8px 16px; cursor: pointer; font-size: 13px; font-weight: 500;
#   transition: background-color 0.2s;
# }
# .lx-control-btn:hover { background: #3367d6; }
# .lx-progress-container {
#   margin-bottom: 8px;
# }
# .lx-progress-slider {
#   width: 100%; margin: 0; appearance: none; height: 6px;
#   background: #ddd; border-radius: 3px; outline: none;
# }
# .lx-progress-slider::-webkit-slider-thumb {
#   appearance: none; width: 18px; height: 18px; background: #4285f4;
#   border-radius: 50%; cursor: pointer;
# }
# .lx-progress-slider::-moz-range-thumb {
#   width: 18px; height: 18px; background: #4285f4; border-radius: 50%;
#   cursor: pointer; border: none;
# }
# .lx-status-text {
#   text-align: center; font-size: 12px; color: #666; margin-top: 4px;
# }
# .lx-text-window {
#   font-family: monospace; white-space: pre-wrap; border: 1px solid #90caf9;
#   padding: 12px; max-height: 260px; overflow-y: auto; margin-bottom: 12px;
#   line-height: 1.6;
# }
# .lx-attributes-panel {
#   background: #fafafa; border: 1px solid #90caf9; border-radius: 6px;
#   padding: 8px 10px; margin-top: 8px; font-size: 13px;
# }
# .lx-current-highlight {
#   border-bottom: 4px solid #ff4444;
#   font-weight: bold;
#   animation: lx-pulse 1s ease-in-out;
# }
# @keyframes lx-pulse {
#   0% { text-decoration-color: #ff4444; }
#   50% { text-decoration-color: #ff0000; }
#   100% { text-decoration-color: #ff4444; }
# }
# .lx-legend {
#   font-size: 12px; margin-bottom: 8px;
#   padding-bottom: 8px; border-bottom: 1px solid #e0e0e0;
# }
# .lx-label {
#   display: inline-block;
#   padding: 2px 4px;
#   border-radius: 3px;
#   margin-right: 4px;
#   color: #000;
# }
# .lx-attr-key {
#   font-weight: 600;
#   color: #1565c0;
#   letter-spacing: 0.3px;
# }
# .lx-attr-value {
#   font-weight: 400;
#   opacity: 0.85;
#   letter-spacing: 0.2px;
# }
#
# /* Add optimizations with larger fonts and better readability for GIFs */
# .lx-gif-optimized .lx-text-window { font-size: 16px; line-height: 1.8; }
# .lx-gif-optimized .lx-attributes-panel { font-size: 15px; }
# .lx-gif-optimized .lx-current-highlight { text-decoration-thickness: 4px; }
# </style>
#     <div class="lx-animated-wrapper lx-gif-optimized">
#       <div class="lx-attributes-panel">
#         <div class="lx-legend">Highlights Legend: <span class="lx-label" style="background-color:#D2E3FC;">audience_impact</span> <span class="lx-label" style="background-color:#C8E6C9;">opinion_statement</span></div>
#         <div id="attributesContainer"></div>
#       </div>
#       <div class="lx-text-window" id="textWindow">
#         **Page 1**
# &quot;&quot;&quot;
# Movie Review - Aladdin
# A Familiar World
# The story of Aladdin does not change from the original. Boy meets girl, then we have our
# main characters motivation for the rest of the plot: get the girl. The girl, in this case, is a
# princess, which of course is a problem, since our main character Aladdin is a “street rat”.
# The plot does not deviate from the original at all. Aladdin finds Genie and he gets the girl,
# after a series of lies and songs. <span class="lx-highlight lx-current-highlight" data-idx="0" style="background-color:#C8E6C9;">I was disappointed how closely it stuck to the original</span>. I was
# hoping it would be more of a retelling than a remake, but either way, <span class="lx-highlight" data-idx="1" style="background-color:#C8E6C9;">it was great to see a
# childhood favorite cartoon brought to life</span>.
# The Characters
# Following the first trailers, <span class="lx-highlight" data-idx="2" style="background-color:#C8E6C9;">I lost all excitement in this movie</span>. <span class="lx-highlight" data-idx="3" style="background-color:#C8E6C9;">I felt they got all the
# characters wrong</span> and I couldn&#x27;t get behind it. I tried my best to go into this movie with an
# open mind and what happened surprised me. <span class="lx-highlight" data-idx="4" style="background-color:#C8E6C9;">Most of the characters grew on me very
# quickly</span>.
# <span class="lx-highlight" data-idx="5" style="background-color:#C8E6C9;">Aladdin — played by Mena Massoud — was by far my favorite character</span>. <span class="lx-highlight" data-idx="6" style="background-color:#C8E6C9;">He brought the
# same charisma that the original cartoon brought</span>. <span class="lx-highlight" data-idx="7" style="background-color:#C8E6C9;">Whenever he was on screen the movie
# was at its best</span>. It didn&#x27;t matter if he was singing, dancing, or just flashing his goofy smile,
# <span class="lx-highlight" data-idx="8" style="background-color:#C8E6C9;">the movie shined when he was there</span>.
# Jasmine was a character that, by the end of the movie, I came around on. <span class="lx-highlight" data-idx="9" style="background-color:#C8E6C9;">Naomi Scott was
# great in the role</span>; my problems were not with how she played the role, but rather how they
# made her look. When I looked at her, <span class="lx-highlight" data-idx="10" style="background-color:#C8E6C9;">I really didn&#x27;t see Jasmine</span>. <span class="lx-highlight" data-idx="11" style="background-color:#C8E6C9;">Her performance was so
# believable that by the end, I did see Jasmine in her</span>.
# Jasmine had one of the bigger changes from cartoon to live action. They made her have
# more of a voice, which is another way of saying they gave her more singing to do. <span class="lx-highlight" data-idx="12" style="background-color:#C8E6C9;">The
# added songs were a welcomed change</span>.
# <span class="lx-highlight" data-idx="13" style="background-color:#C8E6C9;">The Genie was one of my least liked characters</span>. Will Smith did one thing I was very happy
# about: <span class="lx-highlight" data-idx="14" style="background-color:#C8E6C9;">he did not try to be Robin Williams</span>. With that said, <span class="lx-highlight" data-idx="15" style="background-color:#C8E6C9;">he also didn&#x27;t do anything great
# with the character</span>. It seemed like he basically just tried to play himself. If you’re a fan of
# Will Smith, you will most likely enjoy the Genie, but <span class="lx-highlight" data-idx="16" style="background-color:#C8E6C9;">it would have been nice to see Smith
# really try to make the part something special</span>. <span class="lx-highlight" data-idx="17" style="background-color:#C8E6C9;">His delivery on his jokes, and even the way
# he sings some of the most famous songs, you can&#x27;t help but hear “The Fresh Prince” in his
# voice</span>, which for me <span class="lx-highlight" data-idx="18" style="background-color:#D2E3FC;">was distracting</span>.
# <span class="lx-highlight" data-idx="19" style="background-color:#C8E6C9;">Jafar was the weakest character in the film</span>; <span class="lx-highlight" data-idx="20" style="background-color:#C8E6C9;">Marwan Kenzari was not believable as Jafar at
# all</span>. Some of this was his doing, but <span class="lx-highlight" data-idx="21" style="background-color:#C8E6C9;">the rest was the script</span>. <span class="lx-highlight" data-idx="22" style="background-color:#C8E6C9;">Jafar wasn&#x27;t really given too
# much on screen to show what his motives really are</span>. He wants power, and will do anythi

# %%
#Discussion
"""
In the Aladdin movie review, the extractor captured many explicit opinions but produced long, fragmented spans and it didn't tag full audience impact (e.g., “gets you ready for the movie”). 
I think the quality can be improved by lowering the max_char_buffer value maybe to 800~1200, and raise extraction_passes to 2~3 with a low temperature, and strengthen few-shot examples, 
especially for audience impacts and contrastive clauses.
"""

# %% [markdown]
# ---
# ### <a id='toc1_5_8_'></a>[**2.4 Generating LLM Embeddings:**](#toc0_)
#
# LLM embeddings are dense numerical vectors that represent the semantic meaning of text. Generated by Large Language Models, they map words, phrases, or documents into a high-dimensional space where similar concepts are positioned closely together.
#
# Their key advantages are:
#
# *   **Contextual Understanding:** Unlike older methods, LLM embeddings are contextual. The vector for a word like **"bank"** will be different depending on whether it's used in the context of a "river bank" or a "money bank," providing a more nuanced representation of language.
#
# *   **Versatility from Pre-training:** They are pre-trained on vast amounts of text data. This allows them to generalize effectively across various tasks, such as classification, clustering, and similarity detection. They do not require extensive retraining.
#
# <span style="color:green">For the exercise in this section there is no need to re-run the cells, you can use the data that has been saved previously to the corresponding directory.</span>
#
# **Now let's generate some embeddings with Gemini for a sample of our dataset:**

# %%
from google import genai
import pandas as pd
import time
from google.api_core import exceptions

# Let's define our function to get the embeddings with Gemini
def get_gemini_embedding(text: str, model: str="gemini-embedding-001"):
    try:
        result = client.models.embed_content(model=model, contents=[text])
        # 100 requests per minute limit -> 60s / 100 = 0.6s per request
        # buffer time to avoid rate limits
        time.sleep(0.6)
        return result.embeddings
    except exceptions.ResourceExhausted as e:
        print(f"Rate limit exceeded. Waiting to retry... Error: {e}")
        time.sleep(5) # Wait for 5 seconds before the next attempt
        return get_gemini_embedding(text, model) # Retry the request
    except Exception as e:
        print(f"An unexpected error occurred: {e}")
        return None

# %%
total_extractions = 200
train_ratio = 0.8
test_ratio = 0.2

n_train_to_sample = int(total_extractions * train_ratio)
n_test_to_sample = int(total_extractions * test_ratio)
# We use the text column
column_name = 'text'

# This function is to get a stratified sample from our data, meaning to have the same distribution of labels as in the full dataset
def stratified_sample(df: pd.DataFrame, n_samples: int, stratify_col: str = 'emotion') -> pd.DataFrame:
    if n_samples >= len(df):
        return df.copy() # Return a copy if requested sample is larger or equal
    sampled_df = df.groupby(stratify_col, group_keys=False).apply(
        lambda x: x.sample(n=max(0, int(round(len(x) / len(df) * n_samples))))
    )

    # Adjust for rounding errors to get the exact number of samples
    current_samples = len(sampled_df)
    if current_samples < n_samples:
        remaining_indices = df.index.difference(sampled_df.index)
        additional_samples = df.loc[remaining_indices].sample(n=n_samples - current_samples, random_state=42)
        sampled_df = pd.concat([sampled_df, additional_samples])
    elif current_samples > n_samples:
        sampled_df = sampled_df.sample(n=n_samples, random_state=42)
    return sampled_df

print(f"Sampling {n_train_to_sample} rows from the training set...")
train_df_new = stratified_sample(train_df, n_train_to_sample, 'emotion')

print(f"Sampling {n_test_to_sample} rows from the test set...")
test_df_new = stratified_sample(test_df, n_test_to_sample, 'emotion')
# Out:
# Sampling 160 rows from the training set...
# Sampling 40 rows from the test set...
# /var/folders/w5/pvmrnyvn4mv959z40dcm7hrh0000gn/T/ipykernel_35307/2000596105.py:14: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   sampled_df = df.groupby(stratify_col, group_keys=False).apply(
# /var/folders/w5/pvmrnyvn4mv959z40dcm7hrh0000gn/T/ipykernel_35307/2000596105.py:14: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   sampled_df = df.groupby(stratify_col, group_keys=False).apply(

# %%
train_df_new["emotion"].value_counts()
# Out:
# emotion
# fear       51
# anger      38
# joy        36
# sadness    35
# Name: count, dtype: int64

# %%
test_df_new["emotion"].value_counts()
# Out:
# emotion
# fear       13
# anger      10
# joy         9
# sadness     8
# Name: count, dtype: int64

# %%
# Apply the function to the specified column and store the result in a new column 'embeddings'
print("\nGenerating embeddings for the new training set...")
train_df_new['embeddings'] = train_df_new[column_name].apply(get_gemini_embedding)
# Out:
# Generating embeddings for the new training set...

# %%
print("\nGenerating embeddings for the new test set...")
test_df_new['embeddings'] = test_df_new[column_name].apply(get_gemini_embedding)
# Out:
# Generating embeddings for the new test set...

# %%
from google.genai import types

# After getting the embeddings we need to convert the Gemini type ContentDict of the embeddings into a simple list with them
train_df_new['embeddings_values'] = train_df_new["embeddings"].apply(lambda row: list(types.ContentDict(row[0]).values())[0])
test_df_new['embeddings_values'] = test_df_new["embeddings"].apply(lambda row: list(types.ContentDict(row[0]).values())[0])

# %%
train_df_new #We can see the new column with the embeddings
# Out:
#          id                                               text  emotion  \
# 780   10780  @leener00 @libbyfloyd1 @G_Eazy my snap is andr...    anger
# 674   10674  @evanareteos :)) im now writing abt the changi...    anger
# 757   10757  @justinbieber Thank u Justin for this amazing ...    anger
# 82    10082  The liberal outrage over don king saying the N...    anger
# 695   10695  Sometimes the best motivations come from 'prov...    anger
# ...     ...                                                ...      ...
# 3547  40720                        Alt-J - Hunger of the pine.  sadness
# 3298  40471  LORD MAKE ME AN INSTRUMENT OF YOUR PEACE — Whe...  sadness
# 2929  40102  Ill say it again. If I was a Black man Id be a...  sadness
# 2925  40098  Tell me how I'm supposed to feel. #broken #hat...  sadness
# 3526  40699  Amateurs sit and wait for inspiration, the res...  sadness
#
#       intensity                                         embeddings  \
# 780       0.271  [values=[-0.01804998, 0.014986205, -0.00090933...
# 674       0.375  [values=[-0.00550717, -0.008929311, -0.0025068...
# 757       0.312  [values=[-0.011760756, -0.024499612, 0.0163312...
# 82        0.863  [values=[0.015918855, -0.017708927, 0.00227650...
# 695       0.354  [values=[0.0060910885, 0.010345531, 0.01283460...
# ...         ...                                                ...
# 3547      0.235  [values=[0.008939399, -0.006119466, 0.01079806...
# 3298      0.427  [values=[0.011425298, -0.0042333025, 0.0161253...
# 2929      0.729  [values=[-0.017720738, -0.0036618335, 0.001076...
# 2925      0.729  [values=[-0.030602572, -0.0057022925, -0.00638...
# 3526      0.271  [values=[-0.024224006, 0.009118277, 0.01128276...
#
#                                       embeddings_values
# 780   [-0.01804998, 0.014986205, -0.00090933504, -0....
# 674   [-0.00550717, -0.008929311, -0.0025068389, -0....
# 757   [-0.011760756, -0.024499612, 0.016331261, -0.0...
# 82    [0.015918855, -0.017708927, 0.0022765095, -0.0...
# 695   [0.0060910885, 0.010345531, 0.012834609, -0.05...
# ...                                                 ...
# 3547  [0.008939399, -0.006119466, 0.010798063, -0.08...
# 3298  [0.011425298, -0.0042333025, 0.016125351, -0.0...
# 2929  [-0.017720738, -0.0036618335, 0.0010767763, -0...
# 2925  [-0.030602572, -0.0057022925, -0.0063844235, -...
# 3526  [-0.024224006, 0.009118277, 0.011282762, -0.06...
#
# [160 rows x 6 columns]

# %%
test_df_new #We can see the new column with the embeddings
# Out:
#         id                                               text  emotion  \
# 230  30859  incredible that anthony weiner has been caught...      joy
# 182  21245  Hillary Clinton looked the other way to the Sa...     fear
# 21   10878                         Literally fuming fuck sake    anger
# 265  30894  @PhilGlutting Hey There Phil Glutting thank yo...      joy
# 68   10925  Anger, resentment, and hatred are the destroye...    anger
# 323  40836  im thoroughly in love w zen and jumin and i do...  sadness
# 118  21181  @AlaskaGurus @adventuretweets agreed! 😍 an awe...     fear
# 325  40838  @GolfStrat out of Rory starts. What would your...  sadness
# 245  30874   @harrietemmett great minds think alike. #rejoice      joy
# 64   10921  @MaddenFreestyle i turn the game on wanting to...    anger
# 241  30870  @Communism_Kills i get the subway melt and mak...      joy
# 178  21241       Tweeting from the sporadic wifi on the tube      fear
# 147  21210                      Another fun fact: i am afraid     fear
# 74   10931          @danbloom1 beware the fury of a weak king    anger
# 167  21230  It really is amazing the money they give to so...     fear
# 337  40850  aaahhhh! a little @OtisRedding to soothe the s...  sadness
# 136  21199  Ever been really lonely and your phone keeps b...     fear
# 331  40844  yesterday i finished watching penny dreadful a...  sadness
# 286  40799  @kayleighmcenany  @DonaldJTrumpJr Is that real...  sadness
# 27   10884  @RevTrevK @Wolfman93011 @Daraidernation @EROCK...    anger
# 224  30853  @GameGrumps THANK YOU SO MUCH FOR COMING TO DE...      joy
# 20   10877  [ @HedgehogDylan ] *she would frown a bit, fol...    anger
# 145  21208                    Rooney shocking attempted cross     fear
# 59   10916  Note to self ~ Stop laughing at things that of...    anger
# 226  30855  Each day is what you make of it! #goals #chall...      joy
# 123  21186  On @Varneyco/@FoxBusiness to talk latest on #C...     fear
# 6    10863  I think @Sam_Canaday &amp; @KYLEJDOWSON must a...    anger
# 249  30878  @airtelindia have some issues with my broadban...      joy
# 329  40842  Don't be disheartened if you didn't get the ca...  sadness
# 53   10910  Having a baby born too soon is #lifechanging 6...    anger
# 311  40824  On bedrest since I got out of the hospital. U ...  sadness
# 223  30852  Val reminds me of one of the cheerful witches ...      joy
# 279  40792  Donating to Trump puts a damper on a very exci...  sadness
# 88   21151  Really.....#Jumanji 2....w/ The Rock, Jack Bla...     fear
# 179  21242                Southend players always haunt Man U     fear
# 157  21220  @hollywooddivas @TMZ_Sports Idiots like Larry ...     fear
# 184  21247  it's horrible cos no one can relate,  everyone...     fear
# 50   10907  Just joined #pottermore and was sorted into HU...    anger
# 142  21205  @stephenfhayes Mustard gas = hostile work envi...     fear
# 194  30823  @theclobra lol I thought maybe, couldn't decid...      joy
#
#      intensity                                         embeddings  \
# 230      0.380  [values=[-0.02280395, 0.02069193, -0.000340573...
# 182      0.479  [values=[-0.002730555, 0.00785198, -0.01620275...
# 21       0.860  [values=[0.004565768, -0.010073113, -0.0132940...
# 265      0.760  [values=[-0.034564763, 0.009070156, -0.0020970...
# 68       0.375  [values=[0.006805829, 0.009590601, -0.00079551...
# 323      0.458  [values=[0.00336918, -0.03743703, -0.012332446...
# 118      0.208  [values=[-0.03000513, -0.024266208, 0.01600963...
# 325      0.343  [values=[0.03251419, -0.0120953005, 0.00982391...
# 245      0.519  [values=[-0.013035271, 0.0017458068, -0.017289...
# 64       0.500  [values=[-0.02317859, -0.004650827, -0.0013773...
# 241      0.380  [values=[0.0015269195, -0.003343023, 0.0012894...
# 178      0.292  [values=[-0.0066989562, 0.0057921065, -0.01125...
# 147      0.667  [values=[-0.01226142, -0.00048677987, -0.01031...
# 74       0.417  [values=[-0.0057392195, 0.0199813, -0.01062424...
# 167      0.246  [values=[-0.04023646, -0.0033757573, -0.015112...
# 337      0.197  [values=[-0.009578301, -0.006965374, -0.013988...
# 136      0.740  [values=[-0.017594485, -0.02038086, -0.0274361...
# 331      0.312  [values=[-0.019259144, -0.021168273, 0.0303008...
# 286      0.375  [values=[-0.013754529, 0.012150785, 0.01298435...
# 27       0.586  [values=[-0.013165958, -0.038608503, -0.008693...
# 224      0.804  [values=[-0.02887108, -0.022832144, -0.0155585...
# 20       0.500  [values=[-0.015942886, 0.0062166224, -0.009731...
# 145      0.375  [values=[0.0127588855, -0.0021300393, -0.02128...
# 59       0.542  [values=[-0.010816357, -0.012566608, -0.023107...
# 226      0.604  [values=[-0.01992363, 0.021712968, 0.013815594...
# 123      0.604  [values=[-0.039580334, -0.0056183864, -0.00678...
# 6        0.250  [values=[-0.010546908, 0.021585377, 0.00737523...
# 249      0.038  [values=[-0.0021962682, 0.017550863, 0.0038282...
# 329      0.438  [values=[0.014799686, 0.026640678, -0.00012501...
# 53       0.375  [values=[-0.025528934, -0.0049635707, -0.01072...
# 311      0.440  [values=[0.0041351523, -0.0051084706, -0.02860...
# 223      0.521  [values=[-0.01138335, -0.008304243, -0.0052781...
# 279      0.438  [values=[-0.027140783, -0.023588095, -0.004433...
# 88       0.542  [values=[-0.005593506, -0.048560806, 0.0125558...
# 179      0.417  [values=[-0.007465832, -0.025449552, -0.023478...
# 157      0.604  [values=[0.0065804557, 0.0016677211, 0.0106831...
# 184      0.542  [values=[-0.031625725, -0.018231656, -0.013723...
# 50       0.438  [values=[0.0007232955, -0.038711242, 0.0068611...
# 142      0.708  [values=[0.0034173268, 0.014688194, 0.00708017...
# 194      0.312  [values=[-0.009851168, -0.0074269082, -0.00489...
#
#                                      embeddings_values
# 230  [-0.02280395, 0.02069193, -0.00034057387, -0.0...
# 182  [-0.002730555, 0.00785198, -0.016202757, -0.06...
# 21   [0.004565768, -0.010073113, -0.013294056, -0.0...
# 265  [-0.034564763, 0.009070156, -0.0020970262, -0....
# 68   [0.006805829, 0.009590601, -0.0007955102, -0.0...
# 323  [0.00336918, -0.03743703, -0.012332446, -0.064...
# 118  [-0.03000513, -0.024266208, 0.01600963, -0.072...
# 325  [0.03251419, -0.0120953005, 0.009823919, -0.06...
# 245  [-0.013035271, 0.0017458068, -0.017289385, -0....
# 64   [-0.02317859, -0.004650827, -0.001377392, -0.0...
# 241  [0.0015269195, -0.003343023, 0.0012894134, -0....
# 178  [-0.0066989562, 0.0057921065, -0.011250335, -0...
# 147  [-0.01226142, -0.00048677987, -0.010317536, -0...
# 74   [-0.0057392195, 0.0199813, -0.010624246, -0.07...
# 167  [-0.04023646, -0.0033757573, -0.015112562, -0....
# 337  [-0.009578301, -0.006965374, -0.013988109, -0....
# 136  [-0.017594485, -0.02038086, -0.027436184, -0.0...
# 331  [-0.019259144, -0.021168273, 0.030300863, -0.0...
# 286  [-0.013754529, 0.012150785, 0.012984351, -0.05...
# 27   [-0.013165958, -0.038608503, -0.008693953, -0....
# 224  [-0.02887108, -0.022832144, -0.015558547, -0.0...
# 20   [-0.015942886, 0.0062166224, -0.009731274, -0....
# 145  [0.0127588855, -0.0021300393, -0.021284327, -0...
# 59   [-0.010816357, -0.012566608, -0.023107173, -0....
# 226  [-0.01992363, 0.021712968, 0.013815594, -0.062...
# 123  [-0.039580334, -0.0056183864, -0.0067838775, -...
# 6    [-0.010546908, 0.021585377, 0.0073752305, -0.0...
# 249  [-0.0021962682, 0.017550863, 0.0038282655, -0....
# 329  [0.014799686, 0.026640678, -0.00012501857, -0....
# 53   [-0.025528934, -0.0049635707, -0.010728385, -0...
# 311  [0.0041351523, -0.0051084706, -0.028601801, -0...
# 223  [-0.01138335, -0.008304243, -0.0052781655, -0....
# 279  [-0.027140783, -0.023588095, -0.004433104, -0....
# 88   [-0.005593506, -0.048560806, 0.012555859, -0.0...
# 179  [-0.007465832, -0.025449552, -0.02347882, -0.0...
# 157  [0.0065804557, 0.0016677211, 0.010683102, -0.0...
# 184  [-0.031625725, -0.018231656, -0.013723901, -0....
# 50   [0.0007232955, -0.038711242, 0.0068611447, -0....
# 142  [0.0034173268, 0.014688194, 0.0070801787, -0.0...
# 194  [-0.009851168, -0.0074269082, -0.004893037, -0...

# %%
# save them to pickle files
train_df_new.to_pickle("./data/train_df_sample_embeddings.pkl") 
test_df_new.to_pickle("./data/test_df_sample_embeddings.pkl")

# %%
import pandas as pd
# load the pickle files
train_df_new = pd.read_pickle("./data/train_df_sample_embeddings.pkl")
test_df_new = pd.read_pickle("./data/test_df_sample_embeddings.pkl")

# %%
len(train_df_new.iloc[0]["embeddings_values"]) # Gemini embedding dimension is 3072
# Out:
# 3072

# %%
import pandas as pd
import numpy as np
import umap
import plotly.express as px

# Concatenate the training and test data
combined_df = pd.concat([train_df_new, test_df_new], ignore_index=True)

# Prepare the embeddings for UMAP
# Convert the list of embeddings into a 2D numpy array
X_embeddings = np.array(combined_df['embeddings_values'].tolist())

# Apply UMAP for dimensionality reduction
reducer = umap.UMAP(n_components=2, metric='cosine', random_state=28) 
embedding_2d = reducer.fit_transform(X_embeddings)

# Create a DataFrame for plotting
df_plot = pd.DataFrame(embedding_2d, columns=['UMAP1', 'UMAP2'])
df_plot['emotion'] = combined_df['emotion']
df_plot['intensity'] = combined_df['intensity']
df_plot['text'] = combined_df['text']


# Visualize the embeddings with Plotly
fig = px.scatter(
    df_plot,
    x='UMAP1',
    y='UMAP2',
    color='emotion',  # Color points by the 'emotion' column
    hover_data=['text', 'intensity'],  # Show text and intensity on hover
    title='2D UMAP Projection of Text Embeddings'
)

fig.show()
# Out:
# /Users/muhsinchen/miniconda3/envs/DM2025lab2/lib/python3.11/site-packages/umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(

# %% [markdown]
# We can see that even with Gemini's embeddings there doesn't seem to be a clear 2D separation of clusters with our data classes. It could be because emotions are often not discrete. Texts can contain mixed feelings (e.g., "bittersweet") or use similar language to express different emotions, causing their embeddings to be naturally close in semantic space. And also the process of projecting high-dimensional embeddings down to a 2D visualization inevitably loses some information, which can make distinct clusters appear to overlap.

# %% [markdown]
# ---
# ##### <a id='toc1_5_8_1_1_'></a>[**>>> Exercise 4 (Take home):**](#toc0_)
#
# Apply UMAP to the same embeddings to reduce the dimensionality to 3D vectors and plot the 3D graph, discuss the differences and similarities with the 2D graph.

# %%
import umap
import plotly.express as px
import pandas as pd
import numpy as np

X_embeddings = np.array(combined_df['embeddings_values'].tolist())

# 3D UMAP graph
reducer_3d = umap.UMAP(n_components=3, metric='cosine', random_state=28)
embedding_3d = reducer_3d.fit_transform(X_embeddings)

# build 3D DataFrame
df_plot_3d = pd.DataFrame(embedding_3d, columns=['UMAP1', 'UMAP2', 'UMAP3'])
df_plot_3d['emotion'] = combined_df['emotion']
df_plot_3d['intensity'] = combined_df['intensity']
df_plot_3d['text'] = combined_df['text']

# draw 3D scatterplot
fig_3d = px.scatter_3d(
    df_plot_3d,
    x='UMAP1', y='UMAP2', z='UMAP3',
    color='emotion',
    hover_data=['text', 'intensity'],
    title='3D UMAP Projection of Text Embeddings'
)
fig_3d.show()

#Discussion
"""
The similarity is that both the 2D and 3D UMAP projections preserve the general semantic relationships among emotions. 
The four emotion categories still occupy overlapping regions, indicating that Gemini's embeddings encode emotional nuances in a continuous space rather than 
forming perfectly discrete clusters. In my opinion, this suggests that texts expressing similar tones or mixed emotions remain close together in both projections.

The difference is that the 3D projection adds an extra dimension that allows for slightly better separation between emotion clusters, 
especially for samples that appeared overlapped in the 2D space. When rotating the 3D graph, some emotions (e.g., fear and sadness) may appear more spatially 
distinct than before. However, the clusters are still not completely separated—reflecting the natural ambiguity and semantic overlap in emotional language.
"""
# Out:
# /Users/muhsinchen/miniconda3/envs/DM2025lab2/lib/python3.11/site-packages/umap/umap_.py:1952: UserWarning:
#
# n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.

# %% [markdown]
# ---
# ### <a id='toc1_5_9_'></a>[**2.5 Retrieval-Augmented Generation (RAG)**](#toc0_)
#
# `NOTE: This whole section including the exercise is now considered a bonus section, not counted for the main grade.`
#
# RAG (Retrieval-Augmented Generation) is a technique where a language model combines document retrieval with text generation. In RAG, a retrieval system first finds relevant documents or text chunks, and then the language model uses this retrieved information to generate a more informed and accurate response. This method enhances the model's ability to answer questions by grounding its responses in real, external data.
#
# In the following code, we will load a webpage as a document, which allows us to retrieve text from a URL. After loading the content, we will split the document into smaller, manageable chunks, making it easier for our model to process. Then, we'll generate embeddings for these chunks with a specified LLM model (Gemini Embedding Model). These embeddings will be stored in a vector database, which enables us to perform similarity searches. By setting up this retrieval system, we can use a RAG chain to answer questions. The retriever finds relevant text chunks from the document based on a query, and the LLM generates a response by incorporating this retrieved information, making the answers more grounded and accurate.
#
# In this example we use the library langchain, for documentation on more functions of the library you can check the following link: [LangChain Tutorials](https://python.langchain.com/docs/tutorials/)

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_community.document_loaders import WebBaseLoader
from langchain_community.vectorstores import Chroma
from langchain_google_genai import GoogleGenerativeAIEmbeddings

# Function to load, split, and retrieve documents
def load_and_retrieve_docs(url):
    loader = WebBaseLoader(
        web_paths=(url,),
        bs_kwargs=dict() 
    ) 
    docs = loader.load() #We will load the URL that will serve as our data source
    text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=150) #We will divide the URL in chunks of text for easier comparison in the vector space
    splits = text_splitter.split_documents(docs)
    #print(splits) #You can print this to see how the chunks in the url where split
    embeddings = GoogleGenerativeAIEmbeddings(model="models/gemini-embedding-001")
    vectorstore = Chroma.from_documents(documents=splits, embedding=embeddings) #Our vector space for comparison
    return vectorstore.as_retriever()


def format_docs(docs):
    return "\n\n".join(doc.page_content for doc in docs) #Format the retrieved docs in an orderly manner for prompting

# Define the Gemini LLM function
def gemini_llm(question, context):
    system_prompt = "You are a RAG Agent that needs to provide a well structured answer based on the provided question and context."
    formatted_prompt = f"Question: {question}\n\nContext: {context}"
    response, logs = prompt_gemini(input_prompt = formatted_prompt, system_instruction = system_prompt, with_tokens_info = True)
    print(f"logs: \n{logs}")
    # print(f"Retrieved context: \n{context}\n\n") # You can print this to observe the retrieved context
    return response


# Define the RAG chain
def rag_chain(question, retriever):
    retrieved_docs = retriever.invoke(question)
    formatted_context = format_docs(retrieved_docs)
    return gemini_llm(question, formatted_context)
# Out:
# WARNING:langchain_community.utils.user_agent:USER_AGENT environment variable not set, consider setting it to identify your requests.

# %%
url="https://qbotica.com/understanding-artificial-general-intelligence-agi-an-in-depth-overview/"
# Create the retriever
retriever = load_and_retrieve_docs(url)

# Use the RAG chain
result = rag_chain(question="What are the Key Challenges in Realizing AGI’s Full Potential", retriever=retriever)
display(Markdown(result))
# Out:
# logs:
# {'model': 'gemini-2.5-flash-lite', 'input_tokens': 726, 'output_tokens': 125}
# The key challenges in realizing AGI's full potential stem from its fundamental requirements and the ethical considerations surrounding its development. These include:
#
# *   **Learning from Diverse Data:** Unlike narrow AI, which is trained on structured data, AGI needs to learn from unstructured and diverse data sources.
# *   **Computational Power:** The sheer amount of computational resources required to process and learn from these vast, diverse datasets presents a significant hurdle.
# *   **Ethical Concerns:** Addressing crucial ethical issues such as bias and fairness in algorithms, protecting user privacy, and establishing clear accountability for AGI's actions are paramount.

# %% [markdown]
# ##### <a id='toc1_5_9_1_1_'></a>[**Actual answer in the URL:**](#toc0_)
#
# ![pic11.png](pics/pic11.png)
#
# ##### <a id='toc1_5_9_1_2_'></a>[**Content in the URL that might get into the generated answer because of similar semantic meaning:**](#toc0_)
#
# ![pic12.png](pics/pic12.png)
#
# source: https://qbotica.com/understanding-artificial-general-intelligence-agi-an-in-depth-overview/

# %% [markdown]
# ---
# ##### <a id='toc1_5_9_1_3_'></a>[**>>> Bonus Exercise 5 (Take home):**](#toc0_)
#
# `NOTE: This exercise is now considered a bonus one, not counted for the main grade, only as extra points.`
#
# Your task is to test the RAG system with your own chosen URL and analyze its performance.
#
# 1. Find a URL of a webpage with interesting text content to test the RAG pipeline.
# 2. Make a question about the content in the webpage you chose.
# 3. Discuss how good the question was answered by the model, if the model missed important information related to your question.
# 4. Display a screenshot of the real answer in the webpage.

# %%
url = "https://royalchessmall.com/blogs/blog/official-rules-of-chess?srsltid=AfmBOooOfrvxa8xz9MV9zs-D7YUWpCB6ZHtoNjK5pKsBFUYz_7mfREIQ"
retriever = load_and_retrieve_docs(url)

result = rag_chain(question="What are the special rules of chess game?", retriever=retriever)
display(Markdown(result))
# Out:
# logs:
# {'model': 'gemini-2.5-flash-lite', 'input_tokens': 540, 'output_tokens': 133}
# The provided text outlines specific rules for chess games, including:
#
# *   **Pawn Promotion:** When a pawn reaches the eighth rank (the furthest row from its starting position), it can be promoted to an unoccupied queen, rook, bishop, or knight.
# *   **En Passant:** This is a special capture move for pawns. If an opponent's pawn moves two squares forward from its starting position and lands next to your pawn, you can capture the opponent's pawn by moving your pawn diagonally to the square the opponent's pawn skipped.
# *   **Castling:** This rule is mentioned but not detailed in the provided text.

# %%
#Discussion
"""
The RAG answer correctly listed 'pawn promotion', 'en passant', and 'castling', matching the headings and definitions on the page. 
I think the answer is clear but misses some castling conditions (e.g., no pieces in between, neither piece moved, not in check) if they weren't pulled into the retrieved chunks. 
Maybe there are some likely limitations such as retrieval depth(k) may have been too low, or the question is broad.
"""

# %% [markdown]
# ##### <a id='toc1_5_9_1_1_'></a>**Actual answer in the URL:**
#
# ![pic_chess.png](pics/pic_chess.png)
#
# source: https://royalchessmall.com/blogs/blog/official-rules-of-chess?srsltid=AfmBOooOfrvxa8xz9MV9zs-D7YUWpCB6ZHtoNjK5pKsBFUYz_7mfREIQ

# %% [markdown]
# ---
# ### <a id='toc1_5_10_'></a>[**2.6 Few-Shot Prompting Classification:**](#toc0_)
#
# Few-shot prompting is a technique where a Large Language Model (LLM) is given a small number of labeled examples within a prompt to guide its classification. This allows the model to perform a new task with minimal data, avoiding the need for extensive fine-tuning.
#
# In this lab, we will use the Gemini API to perform zero-shot, 1-shot, and 5-shot emotion classification:
#
# *   **Zero-shot:** The model classifies text without any prior examples.
# *   **1-shot:** The model is given one example for each emotion before classifying.
# *   **5-shot:** The model is given five examples per emotion for better context.
#
# To make our implementation robust and efficient, we are incorporating two key features:
#
# 1.  **Structured Output:** We provide the Gemini model with a specific output schema (`Emotions` class). This instructs the model to return *only* a valid emotion label (e.g., `joy`), which makes the output predictable and reliable, minimizing errors.
# 2.  **API Rate Handling:** The code includes a function to manage the requests-per-minute limit of the Gemini API.
#
# We will test the model's performance on a small sample of 20 texts per emotion to ensure the process runs quickly. If the model provides an invalid response, the code will automatically retry the request until a valid classification is received.
#
# **Prompt Structure:**
# `System Instruction -> Task Description -> Examples (if not zero-shot) -> Text to Classify`
#
#
# <span style="color:green">For the exercises in this section there is no need to re-run the cells, you can use the data that has been saved previously to the corresponding directory.</span>

# %%
# Funciton for visualizing confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import itertools

def plot_confusion_matrix(cm, classes, title='Confusion matrix',
                          cmap=sns.cubehelix_palette(as_cmap=True)):
    """
    This function is modified from: 
    http://scikit-learn.org/stable/auto_examples/model_selection/plot_confusion_matrix.html
    """
    classes.sort()
    tick_marks = np.arange(len(classes))    
    
    fig, ax = plt.subplots(figsize=(5,5))
    im = ax.imshow(cm, interpolation='nearest', cmap=cmap)
    ax.figure.colorbar(im, ax=ax)
    ax.set(xticks=np.arange(cm.shape[1]),
           yticks=np.arange(cm.shape[0]),
           xticklabels = classes,
           yticklabels = classes,
           title = title,
           xlabel = 'Predicted label',
           ylabel = 'True label')

    fmt = 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt), horizontalalignment="center", color="white" if cm[i, j] > thresh else "black")
    ylim_top = len(classes) - 0.5
    plt.ylim([ylim_top, -.5])
    plt.tight_layout()
    plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import enum
import os
from tqdm import tqdm
import json
import time
# Define the emotion labels
emotions = ['anger', 'fear', 'joy', 'sadness']
# Define the model to use for few-shot prompting

# Schema for the output, the type enum can be used to make a pool of options if what we want is to classify our text selecting only one of them
class Emotions(enum.StrEnum):
    ANGER = 'anger'
    FEAR = 'fear'
    JOY = 'joy'
    SADNESS = 'sadness'


# Function to handle the rate limits of gemini models
def handle_rate_limit(request_count, first_request_time, max_calls_per_min):
    current_time = time.time()

    # Initialize timer on the first request of a new window
    if request_count == 0:
        first_request_time = current_time

    request_count += 1

    # If the rate limit is reached
    if request_count > max_calls_per_min:
        elapsed_time = current_time - first_request_time
        if elapsed_time < 60:
            wait_time = 60 - elapsed_time
            print(f"Rate limit of {max_calls_per_min} requests per minute reached. Waiting for {wait_time:.2f} seconds.")
            time.sleep(wait_time)

        # Reset for the new window
        request_count = 1
        first_request_time = time.time()
    
    return request_count, first_request_time, max_calls_per_min

# Function to sample examples per emotion category
def sample_few_shots(df, emotions, num_samples=5):
    few_shot_examples = {}
    for emotion in emotions:
        few_shot_examples[emotion] = df[df['emotion'] == emotion].sample(n=num_samples, random_state=42)
    return few_shot_examples

# Function to build the prompt based on the number of examples (few-shot, 1-shot, zero-shot)
def build_prompt(examples, emotions, num_shots=5):
    classification_instructions = """
You will be given a text extracted from social media and your task is to classify the text into one of the following emotion categories: 
"anger" | "fear" | "joy" | "sadness"
    """
    
    prompt = classification_instructions + "\n\n"
    
    if num_shots > 0:
        prompt += f"Examples: \n"
        for emotion in emotions:
            for _, row in examples[emotion].iterrows():
                prompt += f"Text: {row['text']}\nClass: {emotion}\n\n" #Show the examples in the same format it will be shown for the classification text
                if num_shots == 1:  # If 1-shot, break after the first example for each emotion
                    break
    return prompt

# Function to classify using the LLM with retry for incorrect responses
def classify_with_llm(test_text, prompt_base, system_prompt, classes, schema):
    response = None
    while not response or response not in classes:
        full_prompt = f"{prompt_base}\nClassification:\nText: {test_text}\nClass: " #The classification text will leave the emotion label to be filled in by the LLM
        try:
            result = prompt_gemini(input_prompt = [full_prompt], schema = schema, system_instruction = system_prompt)
            # print(f"result: {result} \n")
            # print(f"type: {type(result)}")
            if not result:
                # In case of giving empty responses with temperature 0.0, we set a higher temperature to seek for different responses
                result = prompt_gemini(input_prompt = [full_prompt], schema = schema, system_instruction = system_prompt, temperature=1.0)

            try:
                # If the result is in the correct format it can be parsed using json
                response = json.load(result)
            except:
                # In case it's not in a json friendly format
                # Deleting characters " and ' in case they appear in our response with the class of the text 
                response = result.replace('"', '')    
                response = response.replace("'", "")  

                
        # except exceptions.ResourceExhausted as e:
        except Exception as e:
            print(f"Waiting to retry... Error: {e}")
            time.sleep(15)
            print(f"test_text: {test_text}")
            return classify_with_llm(test_text, prompt_base, system_prompt, classes, schema) # Retry the request


        if response not in classes:  # Retry if not a valid response
            print(f"Invalid response: {response}. Asking for reclassification.")
    return response

# Main function to run the experiment with the option for zero-shot, 1-shot, or 5-shot prompting
def run_experiment(df_train, df_test, num_test_samples=5, num_shots=5):
    # Sample examples for few-shot prompting based on num_shots
    if num_shots > 0:
        few_shot_examples = sample_few_shots(df_train, emotions, num_samples=num_shots) 
        prompt_base = build_prompt(few_shot_examples, emotions, num_shots=num_shots)
    else:
        prompt_base = build_prompt(None, emotions, num_shots=0)  # Zero-shot has no examples

    # System prompt for our classification model:
    system_prompt = "You are an emotion classification model for text data. Do not give empty responses, classify according to the list of possible classes."

    # Prepare to classify the test set
    results_data = []

    print(prompt_base)
    # Sample 20 examples per emotion for the test set to classify
    test_samples = sample_few_shots(df_test, emotions, num_samples=num_test_samples)

    # Variables to handle rate limit of gemini
    request_count = 0
    max_calls_per_min = 15 # Gemini 2.5 Flash Lite has this maximum set in the documentation
    first_request_time = None

    # Classify 20 test examples (5 from each category) and save predictions
    for emotion in emotions:
        for _, test_row in tqdm(test_samples[emotion].iterrows(), desc=f"Processing samples for emotion: {emotion}...", total=num_test_samples):
            test_text = test_row['text']
            request_count, first_request_time, max_calls_per_min = handle_rate_limit(request_count, first_request_time, max_calls_per_min)  # Check and handle rate limit before each API call
            predicted_emotion = classify_with_llm(test_text = test_text, prompt_base = prompt_base, system_prompt = system_prompt, classes = emotions, schema = Emotions)
            # Append the results data:
            results_data.append({
                    'text': test_text,
                    'true_emotion': emotion,
                    'predicted_emotion': predicted_emotion
                })

    # Create dataframe to save the results data
    results_df = pd.DataFrame(results_data)
    
    # Extract just the true and predicted labels for metrics calculations
    true_labels = results_df['true_emotion']
    predictions = results_df['predicted_emotion']

    output_dir = "./results/llm_classification_results"
    os.makedirs(output_dir, exist_ok=True)
    # Save the results
    filename = f"{output_dir}/results_samples_{num_test_samples}_shots_{num_shots}.csv"
    
    # Save the DataFrame to CSV
    results_df.to_csv(filename, index=False)
    print(f"\nResults saved to {filename}")

    # Calculate accuracy
    accuracy = accuracy_score(true_labels, predictions)
    print(f"Accuracy: {accuracy * 100:.2f}%")
    
    # Classification report
    print(classification_report(y_true=true_labels, y_pred=predictions))
    
    # Plot confusion matrix
    cm = confusion_matrix(y_true=true_labels, y_pred=predictions) 
    my_tags = ['anger', 'fear', 'joy', 'sadness']
    plot_confusion_matrix(cm, classes=my_tags, title=f'Confusion matrix for classification with \n{num_shots}-shot prompting')

# %% [markdown]
# **Important: The next part should take around 16 minutes to finish running due to API Rate Limits**
#
# **Note:** You might see an `429 RESOURCE_EXHAUSTED` error when running the following code all at once, this is because the `current API Rate Limit handling cannot reliably find out how many requests we have left per minute` from cell to cell, there is no Gemini feature created for it to get the information from their servers. So, `if you don't want to see the error you can just wait 1 minute` after one cell finished processing. But `even if there is an error showing it is fine`, internally in the code `there is a retry that happens every 15 seconds` until we finish processing our sampled data. `The lab is designed to never reach the total rate limit per day quota.`

# %%
# If you see '429 RESOURCE_EXHAUSTED' errors it's fine, wait until the data gets processed, it will keep retrying until it finishes

# Example of running the experiment with zero-shot prompting
run_experiment(train_df, test_df, num_test_samples=20, num_shots=0)
# Out:
# You will be given a text extracted from social media and your task is to classify the text into one of the following emotion categories:
# "anger" | "fear" | "joy" | "sadness"
# Processing samples for emotion: anger...:  75%|███████▌  | 15/20 [00:10<00:03,  1.33it/s]
# Rate limit of 15 requests per minute reached. Waiting for 49.20 seconds.
# Processing samples for emotion: anger...: 100%|██████████| 20/20 [01:03<00:00,  3.16s/it]
# Processing samples for emotion: fear...:  50%|█████     | 10/20 [00:07<00:07,  1.34it/s]
# Rate limit of 15 requests per minute reached. Waiting for 49.70 seconds.
# Processing samples for emotion: fear...: 100%|██████████| 20/20 [01:03<00:00,  3.17s/it]
# Processing samples for emotion: joy...:  25%|██▌       | 5/20 [00:03<00:11,  1.33it/s]
# Rate limit of 15 requests per minute reached. Waiting for 49.61 seconds.
# Processing samples for emotion: joy...: 100%|██████████| 20/20 [01:04<00:00,  3.20s/it]
# Processing samples for emotion: sadness...:   0%|          | 0/20 [00:00<?, ?it/s]
# Rate limit of 15 requests per minute reached. Waiting for 49.19 seconds.
# Processing samples for emotion: sadness...:  75%|███████▌  | 15/20 [01:00<00:04,  1.13it/s]
# Rate limit of 15 requests per minute reached. Waiting for 48.58 seconds.
# Processing samples for emotion: sadness...: 100%|██████████| 20/20 [01:52<00:00,  5.61s/it]
# Results saved to ./results/llm_classification_results/results_samples_20_shots_0.csv
# Accuracy: 55.00%
#               precision    recall  f1-score   support
#
#        anger       0.45      0.65      0.53        20
#         fear       0.78      0.35      0.48        20
#          joy       0.56      0.75      0.64        20
#      sadness       0.60      0.45      0.51        20
#
#     accuracy                           0.55        80
#    macro avg       0.60      0.55      0.54        80
# weighted avg       0.60      0.55      0.54        80

# %%
# If you see '429 RESOURCE_EXHAUSTED' errors it's fine, wait until the data gets processed, it will keep retrying until it finishes

# Example of running the experiment with 1-shot prompting
run_experiment(train_df, test_df, num_test_samples=20, num_shots=1)
# Out:
# You will be given a text extracted from social media and your task is to classify the text into one of the following emotion categories:
# "anger" | "fear" | "joy" | "sadness"
#
#
# Examples:
# Text: I wonder what would happen if I were to tell some people the truth #savage #uhoh
# Class: anger
#
# Text: Super shitting it about this tattoo #nervous
# Class: fear
#
# Text: Blake lively is flawless
# Class: joy
#
# Text: @happyandbashful Flirt, simper, pout, repeat. Yuck.
# Class: sadness
# Processing samples for emotion: anger...:  75%|███████▌  | 15/20 [00:10<00:03,  1.57it/s]
# Rate limit of 15 requests per minute reached. Waiting for 49.86 seconds.
# Processing samples for emotion: anger...: 100%|██████████| 20/20 [01:03<00:00,  3.19s/it]
# Processing samples for emotion: fear...:  50%|█████     | 10/20 [00:07<00:06,  1.51it/s]
# Rate limit of 15 requests per minute reached. Waiting for 48.53 seconds.
# Processing samples for emotion: fear...: 100%|██████████| 20/20 [01:03<00:00,  3.20s/it]
# Processing samples for emotion: joy...:  25%|██▌       | 5/20 [00:03<00:09,  1.54it/s]
# Rate limit of 15 requests per minute reached. Waiting for 49.11 seconds.
# Processing samples for emotion: joy...: 100%|██████████| 20/20 [08:29<00:00, 25.45s/it]
# Processing samples for emotion: sadness...:   0%|          | 0/20 [00:00<?, ?it/s]
# Rate limit of 15 requests per minute reached. Waiting for 49.81 seconds.
# Processing samples for emotion: sadness...:  75%|███████▌  | 15/20 [01:00<00:04,  1.10it/s]
# Rate limit of 15 requests per minute reached. Waiting for 48.83 seconds.
# Processing samples for emotion: sadness...: 100%|██████████| 20/20 [01:53<00:00,  5.69s/it]
# Results saved to ./results/llm_classification_results/results_samples_20_shots_1.csv
# Accuracy: 63.75%
#               precision    recall  f1-score   support
#
#        anger       0.57      0.85      0.68        20
#         fear       0.73      0.40      0.52        20
#          joy       0.74      0.70      0.72        20
#      sadness       0.60      0.60      0.60        20
#
#     accuracy                           0.64        80
#    macro avg       0.66      0.64      0.63        80
# weighted avg       0.66      0.64      0.63        80

# %%
# If you see '429 RESOURCE_EXHAUSTED' errors it's fine, wait until the data gets processed, it will keep retrying until it finishes

# Example of running the experiment with 5-shot prompting
run_experiment(train_df, test_df, num_test_samples=20, num_shots=5)
# Out:
# You will be given a text extracted from social media and your task is to classify the text into one of the following emotion categories:
# "anger" | "fear" | "joy" | "sadness"
#
#
# Examples:
# Text: I wonder what would happen if I were to tell some people the truth #savage #uhoh
# Class: anger
#
# Text: Recommended reading: Prisoners of Hate by Aaron Beck
# Class: anger
#
# Text: After becoming boiling hot, after slowly melting, my heart is frozen.
# Class: anger
#
# Text: @dcexaminer Democrats and their voters have zero tolerance for honesty. They associate honesty with anger and hate.
# Class: anger
#
# Text: i love that tay &amp; tiff are just sitting at my house while i'm at work 🙃
# Class: anger
#
# Text: Super shitting it about this tattoo #nervous
# Class: fear
#
# Text: @BraveHermione_ + and gives it to hear] 'Please.. I can tell you anything if you want to listen. maybe you're dont afraid anymore of me +
# Class: fear
#
# Text: @LakersTakeover it ain't that serious. #HOUvsNE  #igotbetterthingstodotonightthandie
# Class: fear
#
# Text: horrid having a car n no liscence
# Class: fear
#
# Text: I'm scared that my coworkers are going to submit me to one of those 'wardrobe makeover' shows. #fear #fashion
# Class: fear
#
# Text: Blake lively is flawless
# Class: joy
#
# Text: A cheerful sloth annotated old books about a very good man then the gods ended evil.
# Class: joy
#
# Text: Fee otherwise tricks: palm oil delegation mt jaunty resident: TZxCHLdAQ
# Class: joy
#
# Text: Currently listening to @ScottFoxonair &amp; @KatCallaghan @Z1035Toronto podcasts!! Can you guys please move to #yvr ?  #missyou
# Class: joy
#
# Text: Why have I only just started watching glee this week I am now addicted 🙄  #GLEEK
# Class: joy
#
# Text: @happyandbashful Flirt, simper, pout, repeat. Yuck.
# Class: sadness
#
# Text: @SkyNews err I wasnt gloomy.  17.2 mio people were not gloomy only #remain were #Brexit
# Class: sadness
#
# Text: Feels grim not having your nails done
# Class: sadness
#
# Text: My friends tell me I'm pretty. Trigger tells my I'm ugly. I first was confused but then realised I'm both. Pretty ugly. #tru  #tumblr
# Class: sadness
#
# Text: i got his bitch depress
# Class: sadness
# Processing samples for emotion: anger...:  55%|█████▌    | 11/20 [00:09<00:08,  1.11it/s]
# Error occurred when generating response, error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15, model: gemini-2.5-flash-lite\nPlease retry in 19.58121236s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'model': 'gemini-2.5-flash-lite', 'location': 'global'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '19s'}]}}
# Error occurred when generating response, error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15, model: gemini-2.5-flash-lite\nPlease retry in 19.54667384s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash-lite'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '19s'}]}}
# Waiting to retry... Error: 'NoneType' object has no attribute 'replace'
# test_text: @fluffysoftlouis no no. I insist that you give me your best insult first
# Error occurred when generating response, error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15, model: gemini-2.5-flash-lite\nPlease retry in 4.471634582s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'model': 'gemini-2.5-flash-lite', 'location': 'global'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '4s'}]}}
# Error occurred when generating response, error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15, model: gemini-2.5-flash-lite\nPlease retry in 4.428313524s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash-lite'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '4s'}]}}
# Waiting to retry... Error: 'NoneType' object has no attribute 'replace'
# test_text: @fluffysoftlouis no no. I insist that you give me your best insult first
# Error occurred when generating response, error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15, model: gemini-2.5-flash-lite\nPlease retry in 49.35314938s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash-lite'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '49s'}]}}
# Error occurred when generating response, error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15, model: gemini-2.5-flash-lite\nPlease retry in 49.304867335s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash-lite'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '49s'}]}}
# Waiting to retry... Error: 'NoneType' object has no attribute 'replace'
# test_text: @fluffysoftlouis no no. I insist that you give me your best insult first
# Processing samples for emotion: anger...:  75%|███████▌  | 15/20 [00:57<00:27,  5.44s/it]
# Rate limit of 15 requests per minute reached. Waiting for 2.74 seconds.
# Processing samples for emotion: anger...: 100%|██████████| 20/20 [01:03<00:00,  3.18s/it]
# Processing samples for emotion: fear...:  35%|███▌      | 7/20 [00:05<00:10,  1.20it/s]
# Error occurred when generating response, error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15, model: gemini-2.5-flash-lite\nPlease retry in 19.585559068s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'model': 'gemini-2.5-flash-lite', 'location': 'global'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '19s'}]}}
# Error occurred when generating response, error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15, model: gemini-2.5-flash-lite\nPlease retry in 19.545266795s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash-lite'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '19s'}]}}
# Waiting to retry... Error: 'NoneType' object has no attribute 'replace'
# test_text: Ever been really lonely and your phone keeps blowing up, but you just can’t pick it up and respond to people?  #recluse #issues
# Error occurred when generating response, error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15, model: gemini-2.5-flash-lite\nPlease retry in 4.476827588s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash-lite'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '4s'}]}}
# Error occurred when generating response, error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15, model: gemini-2.5-flash-lite\nPlease retry in 4.44409496s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash-lite'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '4s'}]}}
# Waiting to retry... Error: 'NoneType' object has no attribute 'replace'
# test_text: Ever been really lonely and your phone keeps blowing up, but you just can’t pick it up and respond to people?  #recluse #issues
# Error occurred when generating response, error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15, model: gemini-2.5-flash-lite\nPlease retry in 49.386122523s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'model': 'gemini-2.5-flash-lite', 'location': 'global'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '49s'}]}}
# Error occurred when generating response, error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15, model: gemini-2.5-flash-lite\nPlease retry in 49.350504235s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash-lite'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '49s'}]}}
# Waiting to retry... Error: 'NoneType' object has no attribute 'replace'
# test_text: Ever been really lonely and your phone keeps blowing up, but you just can’t pick it up and respond to people?  #recluse #issues
# Processing samples for emotion: fear...:  50%|█████     | 10/20 [00:52<01:15,  7.59s/it]
# Rate limit of 15 requests per minute reached. Waiting for 3.42 seconds.
# Processing samples for emotion: fear...: 100%|██████████| 20/20 [01:03<00:00,  3.17s/it]
# Processing samples for emotion: joy...:  15%|█▌        | 3/20 [00:02<00:14,  1.15it/s]
# Error occurred when generating response, error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15, model: gemini-2.5-flash-lite\nPlease retry in 19.059518451s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash-lite'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '19s'}]}}
# Error occurred when generating response, error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15, model: gemini-2.5-flash-lite\nPlease retry in 19.021530192s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'model': 'gemini-2.5-flash-lite', 'location': 'global'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '19s'}]}}
# Waiting to retry... Error: 'NoneType' object has no attribute 'replace'
# test_text: If yiu don't respond .o an email within 7 days, you willxbe killed by an animated gif of the girl froa The Ri.g.
# Error occurred when generating response, error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15, model: gemini-2.5-flash-lite\nPlease retry in 3.952719151s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'model': 'gemini-2.5-flash-lite', 'location': 'global'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '3s'}]}}
# Error occurred when generating response, error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15, model: gemini-2.5-flash-lite\nPlease retry in 3.915684975s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'model': 'gemini-2.5-flash-lite', 'location': 'global'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '3s'}]}}
# Waiting to retry... Error: 'NoneType' object has no attribute 'replace'
# test_text: If yiu don't respond .o an email within 7 days, you willxbe killed by an animated gif of the girl froa The Ri.g.
# Error occurred when generating response, error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15, model: gemini-2.5-flash-lite\nPlease retry in 48.854595823s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'model': 'gemini-2.5-flash-lite', 'location': 'global'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '48s'}]}}
# Error occurred when generating response, error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15, model: gemini-2.5-flash-lite\nPlease retry in 48.826253924s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash-lite'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '48s'}]}}
# Waiting to retry... Error: 'NoneType' object has no attribute 'replace'
# test_text: If yiu don't respond .o an email within 7 days, you willxbe killed by an animated gif of the girl froa The Ri.g.
# Processing samples for emotion: joy...:  25%|██▌       | 5/20 [00:49<03:04, 12.27s/it]
# Rate limit of 15 requests per minute reached. Waiting for 3.36 seconds.
# Processing samples for emotion: joy...:  95%|█████████▌| 19/20 [01:02<00:00,  1.13it/s]
# Error occurred when generating response, error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15, model: gemini-2.5-flash-lite\nPlease retry in 18.859649438s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash-lite'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '18s'}]}}
# Error occurred when generating response, error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15, model: gemini-2.5-flash-lite\nPlease retry in 18.820874696s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'model': 'gemini-2.5-flash-lite', 'location': 'global'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '18s'}]}}
# Waiting to retry... Error: 'NoneType' object has no attribute 'replace'
# test_text: @GameGrumps THANK YOU SO MUCH FOR COMING TO DETROIT I'm going to sob joyful rainbows now brb
# Error occurred when generating response, error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15, model: gemini-2.5-flash-lite\nPlease retry in 3.745925162s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash-lite'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '3s'}]}}
# Error occurred when generating response, error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15, model: gemini-2.5-flash-lite\nPlease retry in 3.708982815s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'model': 'gemini-2.5-flash-lite', 'location': 'global'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '3s'}]}}
# Waiting to retry... Error: 'NoneType' object has no attribute 'replace'
# test_text: @GameGrumps THANK YOU SO MUCH FOR COMING TO DETROIT I'm going to sob joyful rainbows now brb
# Error occurred when generating response, error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15, model: gemini-2.5-flash-lite\nPlease retry in 48.637242263s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash-lite'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '48s'}]}}
# Error occurred when generating response, error: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 15, model: gemini-2.5-flash-lite\nPlease retry in 48.594919248s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash-lite'}, 'quotaValue': '15'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '48s'}]}}
# Waiting to retry... Error: 'NoneType' object has no attribute 'replace'
# test_text: @GameGrumps THANK YOU SO MUCH FOR COMING TO DETROIT I'm going to sob joyful rainbows now brb
# Processing samples for emotion: joy...: 100%|██████████| 20/20 [01:49<00:00,  5.46s/it]
# Processing samples for emotion: sadness...:   0%|          | 0/20 [00:00<?, ?it/s]
# Rate limit of 15 requests per minute reached. Waiting for 3.86 seconds.
# Processing samples for emotion: sadness...:  75%|███████▌  | 15/20 [00:14<00:03,  1.56it/s]
# Rate limit of 15 requests per minute reached. Waiting for 49.77 seconds.
# Processing samples for emotion: sadness...: 100%|██████████| 20/20 [01:07<00:00,  3.36s/it]
# Results saved to ./results/llm_classification_results/results_samples_20_shots_5.csv
# Accuracy: 60.00%
#               precision    recall  f1-score   support
#
#        anger       0.55      0.80      0.65        20
#         fear       0.67      0.40      0.50        20
#          joy       0.65      0.65      0.65        20
#      sadness       0.58      0.55      0.56        20
#
#     accuracy                           0.60        80
#    macro avg       0.61      0.60      0.59        80
# weighted avg       0.61      0.60      0.59        80

# %% [markdown]
# ---
# ##### <a id='toc1_5_10_1_1_'></a>[**>>> Exercise 6 (Take home):**](#toc0_)
#
# Compare and discuss the overall results of the zero-shot, 1-shot and 5-shot classification.

# %%
"""
In zero-shot prompting, the model reached 55% accuracy, with fairly unbalanced performance across emotions. 
The model performed better on joy and anger but struggled with fear (has a low recall of 0.35). 
This shows that without examples, the model relied purely on general semantic understanding and tended to confuse emotions that share similar language, 
such as fear and sadness.

In 1-shot prompting, accuracy improved to 63.75%, and the F1-scores became more consistent across classes. 
Providing one labeled example per emotion helped the model understand the expected output format and the contextual tone of each emotion, 
especially improving the classification of anger (recall 0.85) and joy. The confusion matrix shows clearer diagonal dominance, meaning more correct matches 
between true and predicted labels.

In 5-shot prompting, accuracy slightly decreased to 60%. While multiple examples provided richer context, I think
they may have introduced variability in wording that confused the model, especially between fear and sadness. 
In my opinion, the improvement plateau suggests that Gemini's instruction-following behavior benefits from a small number of demonstrations,
but can become inconsistent when exposed to more diverse examples.
"""

# %% [markdown]
# ---
# ##### <a id='toc1_5_10_1_2_'></a>[**>>> Exercise 7 (Take home):**](#toc0_)
#
# **Case Study:** Check the results' files inside the `results/llm_classification_results` directory and find cases where the **text classification improves with more examples** (pred emotion is right with examples), **cases where it does not improve** (pred emotion always wrong) and **cases where the classification got worse with more examples** (pred emotion goes from right to wrong with examples). For this you need to load the results with pandas and handle the data using its dataframe functions. Discuss about the findings.

# %%
import pandas as pd

# load results
zero_df = pd.read_csv("./results/llm_classification_results/results_samples_20_shots_0.csv")
one_df  = pd.read_csv("./results/llm_classification_results/results_samples_20_shots_1.csv")
five_df = pd.read_csv("./results/llm_classification_results/results_samples_20_shots_5.csv")

# rename the columns
zero_df = zero_df.rename(columns={"true_emotion": "true_0", "predicted_emotion": "pred_0"})
one_df  = one_df.rename(columns={"true_emotion": "true_1", "predicted_emotion": "pred_1"})
five_df = five_df.rename(columns={"true_emotion": "true_5", "predicted_emotion": "pred_5"})

# merge three data by text for direct comparison
merged = zero_df.merge(one_df, on="text").merge(five_df, on="text")
merged["true_emotion"] = merged["true_0"]

# %%
# Improved case: from wrong to correct with more examples
improved = merged[
    (merged["pred_0"] != merged["true_emotion"]) &
    (merged["pred_5"] == merged["true_emotion"])
]

# No improvement case: always wrong
no_improvement = merged[
    (merged["pred_0"] != merged["true_emotion"]) &
    (merged["pred_1"] != merged["true_emotion"]) &
    (merged["pred_5"] != merged["true_emotion"])
]

# Worse case: correct in 0-shot but wrong later
worse = merged[
    (merged["pred_0"] == merged["true_emotion"]) &
    (merged["pred_5"] != merged["true_emotion"])
]

print(f"Improved: {len(improved)}")
print(f"No improvement: {len(no_improvement)}")
print(f"Worse: {len(worse)}")
# Out:
# Improved: 8
# No improvement: 26
# Worse: 4

# %%
print("Improved examples:")
print(improved[["text", "true_emotion", "pred_0", "pred_1", "pred_5"]].head(5))

print("\nNo improvement examples:")
print(no_improvement[["text", "true_emotion", "pred_0", "pred_1", "pred_5"]].head(5))

print("\nWorse examples:")
print(worse[["text", "true_emotion", "pred_0", "pred_1", "pred_5"]].head(5))
# Out:
# Improved examples:
#                                                  text true_emotion pred_0  \
# 3    @LeonWobYP b***er off. NCFC is a grudge match :)        anger    joy
# 11  @fluffysoftlouis no no. I insist that you give...        anger    joy
# 12  @Jen_ny69 People will always get offended ever...        anger    joy
# 19                 Eat my ass' is no longer an insult        anger    joy
# 22  @soozclifford Sure have... Sydney are too toug...         fear  anger
#
#    pred_1 pred_5
# 3   anger  anger
# 11  anger  anger
# 12  anger  anger
# 19  anger  anger
# 22   fear   fear
#
# No improvement examples:
#                                                  text true_emotion   pred_0  \
# 2   I think @Sam_Canaday &amp; @KYLEJDOWSON must a...        anger  sadness
# 7   Kik to trade, have fun or a conversation  (kik...        anger      joy
# 17                      #oow16 #sting decent new song        anger      joy
# 20                             @lukeshawtime terrible         fear  sadness
# 24  This is #horrible: Lewis Dunk has begun networ...         fear    anger
#
#      pred_1   pred_5
# 2   sadness  sadness
# 7       joy      joy
# 17      joy      joy
# 20  sadness  sadness
# 24  sadness    anger
#
# Worse examples:
#                                                  text true_emotion   pred_0  \
# 18  @TrueAggieFan oh so that's where Brian was! Wh...        anger    anger
# 46  Be it a rainy day, be it cheerful sunshine, I ...          joy      joy
# 58  @diehimbeertonis She developed her 'forced smi...          joy      joy
# 73  @Eeevah14 don't I know it, try not to fret my ...      sadness  sadness
#
#      pred_1   pred_5
# 18    anger      joy
# 46      joy  sadness
# 58  sadness  sadness
# 73     fear     fear

# %%
#Discussion
"""
By examining several representative samples from each category, I can better understand how the model's performance changes with few-shot prompting.
In the improved cases (e.g., “NCFC is a grudge match :)”), the zero-shot model misclassified sarcasm or emotionally implicit phrases as joy, 
but after seeing examples, the model correctly recognized the anger tone. This suggests that contextual cues such as irony or frustration are better captured when demonstrations are provided.
In contrast, no-improvement cases (e.g., “Kik to trade, have fun or a conversation”) remained consistently wrong across all settings. 
These texts are vague or neutral in tone, lacking explicit affective words, which makes them inherently difficult to classify even with few-shot learning.
Finally, worse cases (e.g., “Oh so that's where Brian was!”) show that additional examples can occasionally confuse the model, biasing it toward more common emotion words like joy or sadness. 
This indicates that few-shot prompting may sometimes introduce unwanted lexical bias if the examples are not balanced.
Overall, in my point of view, few-shot prompting improves recognition of subtle emotions but its effectiveness depends strongly on example diversity and contextual similarity.
"""

# %% [markdown]
# ---
# ### <a id='toc1_5_11_'></a>[**2.7 Extra LLM Related Materials:**](#toc0_)
# So this will be it for the lab, but here are some extra materials if you would like to explore:
#
# - **How to use OpenAI ChatGPT model's API (Not Free API):** [Basics Video](https://www.youtube.com/watch?v=e9P7FLi5Zy8), [Basics GitHub](https://github.com/gkamradt/langchain-tutorials/blob/main/chatapi/ChatAPI%20%2B%20LangChain%20Basics.ipynb), [RAG's Basics Video](https://www.youtube.com/watch?v=9AXP7tCI9PI&t=300s), [RAG's Basics GitHub](https://github.com/techleadhd/chatgpt-retrieval)
#
# - **Advanced topic - QLoRA (Quantized Low-Rank Adapter):** QLoRA is a method used to make fine-tuning large language models more efficient. It works by adding a small, trainable part (LoRA) to a pre-trained model, while keeping the rest of the model frozen. At the same time, it reduces the size of the model’s data using a process called quantization, which makes the model require less memory. This allows you to fine-tune large models without needing as much computational power, making it easier to adapt models for specific tasks. Materials: [Paper GitHub](https://github.com/artidoro/qlora?tab=readme-ov-file), [Llama 3 Application Video](https://www.youtube.com/watch?v=YJNbgusTSF0&t=512s),[Llama 3 Application GitHub](https://github.com/adidror005/youtube-videos/blob/main/LLAMA_3_Fine_Tuning_for_Sequence_Classification_Actual_Video.ipynb)
#
# - **How to Fine-tune and run local LLMs with the `unsloth` library:** [unsloth tutorials](https://docs.unsloth.ai/models/tutorials-how-to-fine-tune-and-run-llms)
#
# - **Google's Agent Development Kit Documentation:** [ADK](https://google.github.io/adk-docs/)
#
# - **Build AI agents with LangGraph:** [LangGraph Documentation](https://langchain-ai.github.io/langgraph/concepts/why-langgraph/)

# %% [markdown]
# ---
